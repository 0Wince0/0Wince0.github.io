# %% [markdown]
# # 실행환경 : 윈도우

# %%
from scipy.stats import ttest_ind
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

# 🔹 한글 폰트 설정 (깨짐 방지)
plt.rc('font', family='Malgun Gothic')

# 그래프에 마이너스 기호 깨지는 문제 해결
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로 설정 (하나의 파일에서 데이터 불러오기)
file_path = "data/시각화_현대_기본_중복제거_차량번호_보혐이력.csv"

# 데이터 불러오기
df = pd.read_csv(file_path)

# %% [markdown]
# # 차량연식에 따른 가격 분포

# %% [markdown]
# #### 차량연식이 가격 변동에 미치는 영향을 보여주고있다.

# %%
# 변수 이름 수정
df['연식'] = df['연식'].astype(int)
df['연식'] = df['연식'].astype(str).str[:4].astype(int)  # 연식을 숫자로 변환
df = df.sort_values(by='연식')

# 연식별 평균 가격 계산
mean_prices = df.groupby('연식')['가격'].mean().reset_index()

# 그래프 그리기
plt.figure(figsize=(15, 8))
sns.scatterplot(x='연식', y='가격', data=df, alpha=0.5, color='lightblue', label="산점도")

# 선 그래프 추가 (빨간색)
plt.plot(mean_prices['연식'], mean_prices['가격'], color='red', linewidth=2, label="평균 가격 추세선")

# x축 눈금 설정 (5년 단위)
years = np.arange(df['연식'].min(), df['연식'].max() + 1, 5)
plt.xticks(years, rotation=90)

# 제목 및 라벨 설정
plt.title('연식에 따른 가격 분포')
plt.xlabel('연식')
plt.ylabel('가격 (만 원)')
plt.legend()

plt.show()

# %% [markdown]
# # 차량시리즈별 가격 분포

# %% [markdown]
# #### 차량 시리즈별 ex) 아반떼, 소나타, 산타페 등등 별 각각 가격이 얼마인지를 나타내주고있다.

# %%
# 조건에 맞는 데이터 필터링
df_filtered = df[(df['내차피해'] == 0) & 
                 (df['타차가해'] == 0) & 
                 (df['전체침수횟수'] == 0)].copy()

# 저가/고급 모델 분류
total_mean = df_filtered['가격'].mean()
model_avg = df_filtered.groupby('모델 종류')['가격'].mean().reset_index()
low_price_threshold = model_avg['가격'].quantile(0.25)
high_price_threshold = model_avg['가격'].quantile(0.75)

model_avg['그룹'] = np.where(
    model_avg['가격'] <= low_price_threshold, '저가', 
    np.where(model_avg['가격'] >= high_price_threshold, '고급', '중간')
)

df_filtered = pd.merge(df_filtered, model_avg[['모델 종류', '그룹']], on='모델 종류')

# 그룹별 통계치 비교
group_stats = df_filtered.groupby('그룹')['가격'].agg(['mean', 'var', 'std', 'count'])
print("저가/고급 모델 통계 비교:")
print(group_stats.round(2))

# 시각화
plt.figure(figsize=(16, 10))

# 모델 정렬 (평균 가격 기준)
model_order = df_filtered.groupby('모델 종류')['가격'].mean().sort_values().index.tolist()

# 모델별 통계값 계산 (분산, 표준편차, Q3)
model_stats = df_filtered.groupby('모델 종류')['가격'].agg(['var', 'std', lambda x: x.quantile(0.75)]).reset_index()
model_stats.columns = ['모델 종류', '분산', '표준편차', 'Q3']

# 박스플롯 그리기
ax = sns.boxplot(
    x='모델 종류', 
    y='가격', 
    data=df_filtered, 
    order=model_order,
    palette={'저가': '#1f77b4', '고급': '#ff7f0e', '중간': '#2ca02c'},
    hue='그룹',
    showfliers=False
)

# 분산과 표준편차를 박스 상단에 표시
for i, model in enumerate(model_order):
    stats = model_stats[model_stats['모델 종류'] == model]
    var = stats['분산'].values[0]
    std = stats['표준편차'].values[0]
    q3 = stats['Q3'].values[0]
    
    ax.text(
        i, 
        q3 + 200,  # Q3 기준으로 200만원 위에 표시
        f"Var: {var:.2f}\nStd: {std:.2f}",
        ha='center',
        va='bottom',
        fontsize=10,
        bbox=dict(facecolor='white', alpha=0.9, edgecolor='gray', boxstyle='round')
    )

# 평균값 계산 및 추가
means = df_filtered.groupby('모델 종류')['가격'].mean()
for i, model in enumerate(model_order):
    mean_price = means[model]
    
    # 평균값 마커 추가 (빨간 점)
    ax.scatter(i, mean_price, color='red', zorder=5, s=100)
    
    # 평균값 텍스트 추가 (굵은 흰색 글자)
    ax.text(
        i, mean_price - 150, f"{mean_price:.0f}",  # y좌표를 평균값보다 100만 원 낮게 설정
        ha='center', va='top', fontsize=10,
        color='white', fontweight='bold',
        # bbox=dict(facecolor='black', edgecolor='none', boxstyle='round,pad=0.3')
    )


# 그래프 설정
plt.title("시리즈별 가격 분포 (저가 vs 고급)", fontsize=18, pad=20)
plt.xlabel('시리즈 종류', fontsize=14, labelpad=15)
plt.ylabel('가격 (만원)', fontsize=14, labelpad=15)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', ls=':')
plt.legend(title='모델 그룹', loc='upper left', fontsize=12)

plt.show()
# Out:
# 저가/고급 모델 통계 비교:
#        mean         var      std  count
# 그룹
# 고급  4084.22  2171180.75  1473.49   2996
# 저가  1830.86   339260.17   582.46   1661
# 중간  2637.46   745878.64   863.64   3230

# %% [markdown]
# # 내차피해금액에 의한 가격변화와 타차가해 금액에 대한 가격변화 비교

# %% [markdown]
# #### 내차피해금액에 의한 가격변화와 타차가해금액에 의한 가격변동이 각각 차이가 나지않는다는것을 확인 할 수 있다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# 🔹 한글 폰트 설정 (깨짐 방지)
plt.rc('font', family='Malgun Gothic')

# 파일 경로 설정
file_path = "data/시각화_현대_기본_중복제거_차량번호_보혐이력.csv"

# 데이터 불러오기
df = pd.read_csv(file_path)

# 이상치 필터링: 타차가해금액이 0 미만인 데이터 제거
df_filtered = df[df["타차가해금액"] >= 0]

# 그래프 크기 설정
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# 한글 폰트 설정
plt.rc('font', family='Malgun Gothic')

# 내차피해금액 vs 가격 변화 (좌측 그래프)
sns.scatterplot(
    ax=axes[0],
    x=df_filtered["내차피해금액"],
    y=df_filtered["가격"],
    alpha=0.5, color="blue"
)
axes[0].set_title("내차피해금액 vs 차량 가격 변화")
axes[0].set_xlabel("내차피해금액 (만원)")
axes[0].set_ylabel("차량 가격 (만원)")
axes[0].grid(alpha=0.3)

# 타차가해금액 vs 가격 변화 (우측 그래프)
sns.scatterplot(
    ax=axes[1],
    x=df_filtered["타차가해금액"],
    y=df_filtered["가격"],
    alpha=0.5, color="red"
)
axes[1].set_title("타차가해금액 vs 차량 가격 변화")
axes[1].set_xlabel("타차가해금액 (만원)")
axes[1].set_ylabel("차량 가격 (만원)")
axes[1].grid(alpha=0.3)

# 그래프 표시
plt.tight_layout()
plt.show()

# %% [markdown]
# # 주행거리에 따른 평균 가격변화

# %% [markdown]
# #### 차량 주행거리 증가에 따른 가격변화를 평균을 내서 그래프로 확인하고있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 그래프에 한글 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 그래프에 마이너스 기호 깨지는 문제 해결
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로 설정
file_path = "data/시각화_현대_기본_중복제거_차량번호_보혐이력.csv"

# 데이터 불러오기
df = pd.read_csv(file_path)

# 조건에 맞는 데이터 필터링
df_filtered = df[(df['내차피해'] == 0) & 
                 (df['타차가해'] == 0) & 
                 (df['전체침수횟수'] == 0)].copy()

# 주행거리를 10000km 단위로 그룹화
df_filtered['주행거리_그룹'] = ((df_filtered['주행거리'] // 10000) + 1) * 10000

# 모델별로 그룹화하고 평균 가격 계산
grouped = df_filtered.groupby(['주행거리_그룹'])['가격'].mean().reset_index()

# 데이터 타입 변환
grouped.loc[:, '주행거리_그룹'] = grouped['주행거리_그룹'].astype(int)
grouped.loc[:, '가격'] = grouped['가격'].astype(float)

# 주행거리 그룹이 400,000km 이하인 데이터 필터링
grouped = grouped[grouped['주행거리_그룹'] <= 400000]

plt.figure(figsize=(12, 8))

# 그래프 그리기 (기본 파란색으로 설정)
plt.bar(grouped['주행거리_그룹'].astype(str), grouped['가격'], color='#1f77b4')  # 기본 파란색 설정

# y축 범위 설정
plt.ylim(0, grouped['가격'].max() * 1.1)

# 데이터 포인트 표시
for i, v in enumerate(grouped['가격']):
    plt.text(i, v, f'{v:.0f}', ha='center', va='bottom', fontsize=8)

plt.title(f"주행거리에 따른 평균 가격 변화", fontsize=16, pad = 20)
plt.xlabel('주행거리 (km)', fontsize=14, labelpad=15)
plt.ylabel('평균 가격 (만원)', fontsize=14, labelpad=15)
plt.ylim(0, 5000)

# x축 레이블 설정 시 정수형으로 변환하여 소수점 제거
plt.xticks(ticks=range(len(grouped)), labels=[f"{int(x):,}" for x in grouped['주행거리_그룹']], rotation=45)

plt.tight_layout()

# 그래프를 JPG 파일로 저장
plt.savefig('bar_average_price_by_mileage.jpg', format='jpg', dpi=300)

plt.show()

# %% [markdown]
# # 주행거리 증가여부에 따른 분포 (산포도 및 선형회귀)

# %% [markdown]
# #### 차량 주행거리 증가에 따른 가격변화를 평균을 내서 산포도 및 선형회귀 그래프로 확인하고있다.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# 그래프에 한글 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 그래프에 마이너스 기호 깨지는 문제 해결
plt.rcParams['axes.unicode_minus'] = False

# 파일 경로 설정
file_path = "data/시각화_현대_기본_중복제거_차량번호_보혐이력.csv"

# 데이터 불러오기
df = pd.read_csv(file_path)

# 조건에 맞는 데이터 필터링
df_filtered = df[(df['내차피해'] == 0) & 
                 (df['타차가해'] == 0) & 
                 (df['전체침수횟수'] == 0)].copy()

# 데이터 타입 변환
df_filtered.loc[:, '주행거리'] = df_filtered['주행거리'].astype(int)
df_filtered.loc[:, '가격'] = df_filtered['가격'].astype(float)

# 주행거리 그룹이 400,000km 이하인 데이터 필터링
df_filtered = df_filtered[df_filtered['주행거리'] <= 400000]

# 모델 종류별 평균 가격 계산 및 정렬
grouped = df_filtered.groupby(['주행거리'])['가격'].mean().reset_index()

# 선형 회귀 모델 생성 및 학습
mileage = grouped['주행거리'].values.reshape(-1, 1)
prices = grouped['가격'].values

model = LinearRegression()
model.fit(mileage, prices)

# 예측된 가격 계산
predicted_prices = model.predict(mileage)

# 회귀 계수 및 절편
slope = model.coef_[0]  # 주행거리 1km당 가격 변화량 (만원)
intercept = model.intercept_

# 초기 가격 설정 (주행거리=0일 때의 가격)
initial_price = intercept

# 주행거리 10,000km당 감소율 계산
decrease_per_10000km = slope * 10000
percentage_decrease_per_10000km = (decrease_per_10000km / initial_price) * 100

# 결과 출력
print(f"주행거리 1km당 평균 가격 감소량: {slope:.2f} 만원")
print(f"주행거리 10,000km당 평균 가격 감소량: {decrease_per_10000km:.2f} 만원")
print(f"주행거리 10,000km당 평균 감소율: {percentage_decrease_per_10000km:.2f}%")

# 그래프 그리기
plt.figure(figsize=(12, 8))

# 산점도 그리기 (원의 크기 키우기)
plt.scatter(grouped['주행거리'], grouped['가격'], color='#1f77b4', edgecolor='black', alpha=0.7, s=200)

# 선형 회귀선 추가 (label 추가)
plt.plot(grouped['주행거리'], predicted_prices, color='red', linewidth=2.5, label=f'y = {slope:.2f}x + {intercept:.2f}')

# 그래프 설정
plt.title("주행거리에 따른 가격 분포", fontsize=16, pad=20)
plt.xlabel('주행거리 (km)', fontsize=14, labelpad=15)
plt.ylabel('가격 (만원)', fontsize=14, labelpad=15)
plt.xlim(0, 400000)
plt.ylim(0, max(prices) * 1.1)

# 범례를 그래프 안 우측 상단에 배치
plt.legend(loc='upper right', fontsize=12)

plt.tight_layout()

# 그래프를 JPG 파일로 저장
plt.savefig('scatter_price_by_mileage.jpg', format='jpg', dpi=300)

# 그래프 표시
plt.show()
# Out:
# 주행거리 1km당 평균 가격 감소량: -0.02 만원
# 주행거리 10,000km당 평균 가격 감소량: -155.59 만원
# 주행거리 10,000km당 평균 감소율: -3.99%

# %% [markdown]
# # 차량배지란?
# ###  배지 : 차량의 등급이나 옵션 패키지를 의미하며, 기본형/프리미엄/스포츠 등으로 나뉨.
#
# ###  세부 배지 : 배지를 더 세분화한 정보로, 블랙에디션, 익스클루시브 등 특정 트림이나 특별 사양을 나타냄.

# %% [markdown]
# # 배지 클러스터링

# %%
#쏘나타
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# 1) Sonata 추출
sonata = df[df["모델명"].str.contains("쏘나타")]
Sonata = sonata.groupby('배지')['가격'].mean().sort_values().reset_index()
Sonata
    
# 3) 결측치 처리 (ffill 예시)
Sonata.ffill(inplace=True)

# 4) 중복 제거
Sonata.drop_duplicates(inplace=True)

# 5) 특정 컬럼 기준 정렬 (예: 마지막 수정일이 존재한다고 가정)
if "마지막 수정일" in Sonata.columns:
    Sonata.sort_values(by="마지막 수정일", ascending=True, inplace=True)

# -------------------------------------------------
#   여기서부터 K-means를 이용한 가격대 라벨링
# -------------------------------------------------

# A) K-means 클러스터링에 사용할 데이터(X): 가격만 단일 컬럼 사용
X = Sonata[['가격']]

# B) 군집 개수(k) 지정 후 K-means 수행
kmeans = KMeans(n_clusters=4, random_state=42)
Sonata['cluster'] = kmeans.fit_predict(X)

# C) 각 군집의 중심(평균 가격) 확인
centers = kmeans.cluster_centers_
print("클러스터별 중심(평균 가격):", centers.ravel())

# D) 군집 번호(cluster)가 가격대 순서로 정렬되지 않았을 수 있으므로
#    중심값(centers)을 기준으로 '가장 낮은 가격대→가장 높은 가격대' 순서로 재매핑
sorted_cluster_idxs = np.argsort(centers.ravel())
cluster_map = {}
for new_label, old_label in enumerate(sorted_cluster_idxs):
    cluster_map[old_label] = new_label

Sonata['cluster_price_order'] = Sonata['cluster'].map(cluster_map)

# E) 결과 확인을 위해 가격 오름차순 재정렬
Sonata.sort_values('가격', inplace=True)
display(Sonata.head(30))  # 결과 일부 확인
# Out:
# 클러스터별 중심(평균 가격): [1133.21387991 2377.14815607  814.42424242 1626.48981051]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#                 배지           가격  cluster  cluster_price_order
# 0          Y20 프라임   730.000000        2                    0
# 1          CVVL 모던   749.500000        2                    0
# 2         CVVL 스마트   755.000000        2                    0
# 3          2.4 스타일   785.000000        2                    0
# 4     1.7 디젤 케어플러스   840.000000        2                    0
# 5          LPI 스마트   866.666667        2                    0
# 6   1.6 터보 와일드 버건디   890.000000        2                    0
# 7       1.7 디젤 스마트   899.227273        2                    0
# ...

# %% [markdown]
# ## 배지별 막대그래프

# %% [markdown]
# #### 배지값이 증가할수록 가격도 단계적으로 상승한다

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(20, 10))
plt.grid(True, linestyle='--', linewidth=1, alpha=0.5)

# 막대 그래프 (x=cluster, y=가격, hue=세부 배지)
ax = sns.barplot(
    x='cluster_price_order',
    y='가격',
    data=Sonata,
    hue='배지',
    palette='Blues',
    dodge=False
)

# ------------------------------------------------
# (A) 각 "cluster_price_order"별 평균 가격 계산
# ------------------------------------------------
centers = Sonata.groupby('cluster_price_order')['가격'].mean().to_dict()
# 예: {0: 1326.5, 1: 3217.0, 2: 404.8, 3: 2151.8} (실제 값은 상황에 따라 달라질 수 있음)

# x축 최대값 (텍스트를 오른쪽에 표시하기 위해)
x_min, x_max = ax.get_xlim()

for rank, center_price in centers.items():
    # 1) 수평선: 해당 등급의 평균 가격 위치에 점선
    plt.axhline(y=center_price, color='blue', linestyle='--', linewidth=2, alpha=0.7)
    
    # 2) 텍스트: 그래프 오른쪽 끝 근처에 "등급 N = ~~~" 표시
    #    y값은 선보다 살짝 위로 (예: + 10)
    plt.text(
        x=x_max - 3.5, 
        y=center_price + 10,
        s=f"등급 {rank} = {center_price:.1f}",
        color='red',
        fontsize=10
    )

plt.title("<쏘나타 : 배지 가격 등급>", fontsize=20, weight='bold', pad=20)
plt.xlabel("배지", fontsize=18, labelpad=15, weight='bold')
plt.ylabel("가격(단위:만원)", fontsize=18, labelpad=15, weight='bold')
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)

# 범례 설정
plt.legend(loc='upper left', fontsize=3)

plt.show()

# %% [markdown]
# ## 배지별 박스플롯

# %% [markdown]
# #### 배지별 가격 분포를 박스플롯을 통해 각 배지 범주 안에서도 확인 할 수 있다
# #### 배지 등급이 높을수록 가격 자체도 오르고, 높은 가격대가 나타난다.

# %%
# 위에서 생성한 "Sonata" DataFrame을 그대로 사용하여 박스플롯
plt.figure(figsize=(15, 10))
plt.grid(True, linestyle='--', linewidth=1, alpha=0.7)

# 박스플롯: x축은 'cluster' (또는 'cluster_price_order'를 사용), y축은 '가격'
sns.boxplot(
    x='cluster_price_order',   # 또는 x='cluster_price_order'로 사용할 수 있음
    y='가격',
    data=Sonata,
    palette='Set3',   # 원하는 색상 팔레트 
    showfliers=True,  # 이상치 표시
    width=0.6
)

plt.title("[쏘나타 : 배지별 가격 분포]", fontsize=20, weight='bold')
plt.xlabel("배지", fontsize=18, weight='bold')
plt.ylabel("가격(단위:만원)", fontsize=18, weight='bold')
plt.ylim(0, 4500)
plt.yticks(np.arange(0, 4501, 500), fontsize=15)
plt.xticks(fontsize=15)

plt.show()
# Out:
# C:\Users\hbi\AppData\Local\Temp\ipykernel_21940\1688920793.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# # 세부배지별 클로스터링

# %%
#쏘나타
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# 1) Sonata 추출
sonata = df[df["모델명"].str.contains("쏘나타")]
Sonata = sonata.groupby('세부 배지')['가격'].mean().sort_values().reset_index()
Sonata
    
# 3) 결측치 처리 (ffill 예시)
Sonata.ffill(inplace=True)

# 4) 중복 제거
Sonata.drop_duplicates(inplace=True)

# 5) 특정 컬럼 기준 정렬 (예: 마지막 수정일이 존재한다고 가정)
if "마지막 수정일" in Sonata.columns:
    Sonata.sort_values(by="마지막 수정일", ascending=True, inplace=True)

# -------------------------------------------------
#   여기서부터 K-means를 이용한 가격대 라벨링
# -------------------------------------------------

# A) K-means 클러스터링에 사용할 데이터(X): 가격만 단일 컬럼 사용
X = Sonata[['가격']]

# B) 군집 개수(k) 지정 후 K-means 수행
kmeans = KMeans(n_clusters=4, random_state=42)
Sonata['cluster'] = kmeans.fit_predict(X)

# C) 각 군집의 중심(평균 가격) 확인
centers = kmeans.cluster_centers_
print("클러스터별 중심(평균 가격):", centers.ravel())

# D) 군집 번호(cluster)가 가격대 순서로 정렬되지 않았을 수 있으므로
#    중심값(centers)을 기준으로 '가장 낮은 가격대→가장 높은 가격대' 순서로 재매핑
sorted_cluster_idxs = np.argsort(centers.ravel())
cluster_map = {}
for new_label, old_label in enumerate(sorted_cluster_idxs):
    cluster_map[old_label] = new_label

Sonata['cluster_price_order'] = Sonata['cluster'].map(cluster_map)

# E) 결과 확인을 위해 가격 오름차순 재정렬
Sonata.sort_values('가격', inplace=True)
display(Sonata.head(30))  # 결과 일부 확인
# Out:
# 클러스터별 중심(평균 가격): [1379.39351317 2481.92589355  975.50779133 1932.51350332]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#         세부 배지           가격  cluster  cluster_price_order
# 0        최고급형   730.000000        2                    0
# 1         스페셜  1068.166667        2                    0
# 2   (세부등급 없음)  1128.356707        2                    0
# 3      모던 스페셜  1182.666667        0                    1
# 4         경제형  1330.000000        0                    1
# 5    프리미엄 스페셜  1343.333333        0                    1
# 6         스타일  1382.658537        0                    1
# 7         고급형  1450.000000        0                    1
# 8          모던  1458.843478        0                    1
# ...

# %% [markdown]
# ## 세부배지별 막대그래프

# %% [markdown]
# #### 세부배지 값이 커질수록 평균 가격도 단계적으로 상승하고 있다

# %%
plt.figure(figsize=(20, 10))
plt.grid(True, linestyle='--', linewidth=1, alpha=0.5)

# 막대 그래프 (x=cluster, y=가격, hue=세부 배지)
ax = sns.barplot(
    x='cluster_price_order',
    y='가격',
    data=Sonata,
    hue='세부 배지',
    palette='Blues',
    dodge=False
)

# ------------------------------------------------
# (A) 각 "cluster_price_order"별 평균 가격 계산
# ------------------------------------------------
centers = Sonata.groupby('cluster_price_order')['가격'].mean().to_dict()
# 예: {0: 1326.5, 1: 3217.0, 2: 404.8, 3: 2151.8} (실제 값은 상황에 따라 달라질 수 있음)

# x축 최대값 (텍스트를 오른쪽에 표시하기 위해)
x_min, x_max = ax.get_xlim()

for rank, center_price in centers.items():
    # 1) 수평선: 해당 등급의 평균 가격 위치에 점선
    plt.axhline(y=center_price, color='blue', linestyle='--', linewidth=2, alpha=0.7)
    
    # 2) 텍스트: 그래프 오른쪽 끝 근처에 "등급 N = ~~~" 표시
    #    y값은 선보다 살짝 위로 (예: + 10)
    plt.text(
        x=x_max - 3.5, 
        y=center_price + 10,
        s=f"등급 {rank} = {center_price:.1f}",
        color='red',
        fontsize=10
    )

plt.title("<쏘나타 : 세부배지 가격 등급>", fontsize=20, weight='bold', pad=20)
plt.xlabel("세부 배지", fontsize=18, labelpad=15, weight='bold')
plt.ylabel("가격(단위:만원)", fontsize=18, labelpad=15, weight='bold')
plt.xticks(fontsize=18)

# 범례 설정
plt.legend(loc='upper left', fontsize=10)

plt.show()

# %% [markdown]
# ## 세부배지별 박스플롯

# %% [markdown]
# #### 박스플롯을 통해, 배지 등급이 높을수록 전반적 가격 수준뿐만 아니라 분포 폭도 커진다.

# %%
# 위에서 생성한 "Sonata" DataFrame을 그대로 사용하여 박스플롯
plt.figure(figsize=(15, 10))
plt.grid(True, linestyle='--', linewidth=1, alpha=0.7)

# 박스플롯: x축은 'cluster' (또는 'cluster_price_order'를 사용), y축은 '가격'
sns.boxplot(
    x='cluster_price_order',   # 또는 x='cluster_price_order'로 사용할 수 있음
    y='가격',
    data=Sonata,
    palette='Set3',   # 원하는 색상 팔레트 
    showfliers=True,  # 이상치 표시
    width=0.6
)

plt.title("[쏘나타 : 세부배지별 가격 분포]", fontsize=20, weight='bold')
plt.xlabel("세부배지", fontsize=18, weight='bold')
plt.ylabel("가격(단위:만원)", fontsize=18, weight='bold')
plt.ylim(0, 5000)
plt.yticks(np.arange(0, 5001, 500), fontsize=16)
plt.xticks(fontsize=15)

plt.show()
# Out:
# C:\Users\hbi\AppData\Local\Temp\ipykernel_21940\304443405.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
