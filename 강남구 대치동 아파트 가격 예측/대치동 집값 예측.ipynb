# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

train = pd.read_csv('/project/datacamp/team3/t3user2/과제/train.csv')
test = pd.read_csv('/project/datacamp/team3/t3user2/과제/test.csv')
sample = pd.read_csv('/project/datacamp/team3/t3user2/과제/sample_submission.csv')
interest_rate = pd.read_csv('/project/datacamp/team3/t3user1/interest_rate.csv',encoding='cp949')

# %%
from matplotlib import font_manager , rc
font_path = '/usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family = font)

# %% [markdown]
# ## 데이터의 타입 및 형태 확인

# %%
display(train.head(),train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5987 entries, 0 to 5986
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      5987 non-null   object
#  1   sigungu                 5987 non-null   object
#  2   jibun                   5987 non-null   object
#  3   apt_name                5987 non-null   object
#  4   exclusive_use_area      5987 non-null   float64
#  5   transaction_year_month  5987 non-null   int64
#  6   transaction_day         5987 non-null   int64
#  7   transaction_real_price  5987 non-null   int64
#  8   floor                   5987 non-null   int64
#  9   year_of_completion      5987 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 467.9+ KB
#            id        sigungu jibun apt_name  exclusive_use_area  \
# 0  TRAIN_0000  서울특별시 강남구 대치동   503    개포우성1              158.54
# 1  TRAIN_0001  서울특별시 강남구 대치동   503    개포우성1              127.61
# 2  TRAIN_0002  서울특별시 강남구 대치동   503    개포우성1              127.61
# 3  TRAIN_0003  서울특별시 강남구 대치동   503    개포우성1              127.61
# 4  TRAIN_0004  서울특별시 강남구 대치동   503    개포우성1               84.81
#
#    transaction_year_month  transaction_day  transaction_real_price  floor  \
# 0                  201401                7                  174000     13
# 1                  201401                9                  157500      6
# 2                  201401               19                  150000      5
# 3                  201402               10                  152000      9
# 4                  201402               10                  116000      3
#
#    year_of_completion
# 0                1983
# 1                1983
# 2                1983
# 3                1983
# 4                1983
# None

# %% [markdown]
# ## 타켓의 평균값 구하기

# %%
# 우리가 만든 모델이 의미 있는지 판단하려면 평균보다는 정확한 결과를 내야한다

mean_apt_price = round(train['transaction_real_price'].mean())
display(mean_apt_price)
# Out:
# 158145

# %% [markdown]
# ## test와 train 데이터를 합치기

# %%
train['train_test'] = 'train'
test['train_test'] = 'test'
all_data = pd.concat([train,test])
all_data = all_data.reset_index(drop=True)

display(train,test,all_data)
# Out:
#               id        sigungu jibun apt_name  exclusive_use_area  \
# 0     TRAIN_0000  서울특별시 강남구 대치동   503    개포우성1              158.54
# 1     TRAIN_0001  서울특별시 강남구 대치동   503    개포우성1              127.61
# 2     TRAIN_0002  서울특별시 강남구 대치동   503    개포우성1              127.61
# 3     TRAIN_0003  서울특별시 강남구 대치동   503    개포우성1              127.61
# 4     TRAIN_0004  서울특별시 강남구 대치동   503    개포우성1               84.81
# ...          ...            ...   ...      ...                 ...
# 5982  TRAIN_5982  서울특별시 강남구 대치동   511  한보미도맨션2              190.47
# 5983  TRAIN_5983  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 5984  TRAIN_5984  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 5985  TRAIN_5985  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 5986  TRAIN_5986  서울특별시 강남구 대치동   992      현대1               84.27
#
#       transaction_year_month  transaction_day  transaction_real_price  floor  \
# 0                     201401                7                  174000     13
# 1                     201401                9                  157500      6
# 2                     201401               19                  150000      5
# 3                     201402               10                  152000      9
# 4                     201402               10                  116000      3
# ...                      ...              ...                     ...    ...
# 5982                  202205                9                  507500      8
# 5983                  202206               24                  380000     10
# 5984                  202206               24                  380000     10
# 5985                  202207               12                  380000      7
# 5986                  202208               16                  205000     13
#
#       year_of_completion train_test
# 0                   1983      train
# 1                   1983      train
# 2                   1983      train
# 3                   1983      train
# 4                   1983      train
# ...                  ...        ...
# 5982                1985      train
# 5983                1985      train
# 5984                1985      train
# 5985                1985      train
# 5986                1990      train
#
# [5987 rows x 11 columns]
#             id        sigungu jibun apt_name  exclusive_use_area  \
# 0    TEST_0000  서울특별시 강남구 대치동   977   (977-)               77.97
# 1    TEST_0001  서울특별시 강남구 대치동   977   (977-)               59.99
# 2    TEST_0002  서울특별시 강남구 대치동   503    개포우성1               84.81
# 3    TEST_0003  서울특별시 강남구 대치동   503    개포우성1               84.81
# 4    TEST_0004  서울특별시 강남구 대치동   503    개포우성1               84.81
# ..         ...            ...   ...      ...                 ...
# 191  TEST_0191  서울특별시 강남구 대치동   511  한보미도맨션2               84.96
# 192  TEST_0192  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 193  TEST_0193  서울특별시 강남구 대치동   511  한보미도맨션2              190.47
# 194  TEST_0194  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 195  TEST_0195  서울특별시 강남구 대치동   992      현대1               84.27
#
#      transaction_year_month  transaction_day  floor  year_of_completion  \
# 0                    202304               10      2                2021
# 1                    202304               10      2                2021
# 2                    202301               13      3                1983
# 3                    202301               19      9                1983
# 4                    202302               15      5                1983
# ..                      ...              ...    ...                 ...
# 191                  202306                9      1                1985
# 192                  202306               19      1                1985
# 193                  202306               21     13                1985
# 194                  202306               23     12                1985
# 195                  202303               23      3                1990
#
#     train_test
# 0         test
# 1         test
# 2         test
# 3         test
# 4         test
# ..         ...
# 191       test
# 192       test
# 193       test
# 194       test
# 195       test
#
# [196 rows x 10 columns]
#               id        sigungu jibun apt_name  exclusive_use_area  \
# 0     TRAIN_0000  서울특별시 강남구 대치동   503    개포우성1              158.54
# 1     TRAIN_0001  서울특별시 강남구 대치동   503    개포우성1              127.61
# 2     TRAIN_0002  서울특별시 강남구 대치동   503    개포우성1              127.61
# 3     TRAIN_0003  서울특별시 강남구 대치동   503    개포우성1              127.61
# 4     TRAIN_0004  서울특별시 강남구 대치동   503    개포우성1               84.81
# ...          ...            ...   ...      ...                 ...
# 6178   TEST_0191  서울특별시 강남구 대치동   511  한보미도맨션2               84.96
# 6179   TEST_0192  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 6180   TEST_0193  서울특별시 강남구 대치동   511  한보미도맨션2              190.47
# 6181   TEST_0194  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 6182   TEST_0195  서울특별시 강남구 대치동   992      현대1               84.27
#
#       transaction_year_month  transaction_day  transaction_real_price  floor  \
# 0                     201401                7                174000.0     13
# 1                     201401                9                157500.0      6
# 2                     201401               19                150000.0      5
# 3                     201402               10                152000.0      9
# 4                     201402               10                116000.0      3
# ...                      ...              ...                     ...    ...
# 6178                  202306                9                     NaN      1
# 6179                  202306               19                     NaN      1
# 6180                  202306               21                     NaN     13
# 6181                  202306               23                     NaN     12
# 6182                  202303               23                     NaN      3
#
#       year_of_completion train_test
# 0                   1983      train
# 1                   1983      train
# 2                   1983      train
# 3                   1983      train
# 4                   1983      train
# ...                  ...        ...
# 6178                1985       test
# 6179                1985       test
# 6180                1985       test
# 6181                1985       test
# 6182                1990       test
#
# [6183 rows x 11 columns]

# %% [markdown]
# ## 날짜 데이터
# transaction_year_month와 transaction_day와 분리되어 있어 불편하니 사용하기 편한 datetime으로 변경

# %%
def preprocess_tran_date(x):
    if type(x) == int:
        if x < 10 :
            return '0' + str(x)
        else :
            return str(x)
        
all_data['transaction_day'] = all_data['transaction_day'].apply(preprocess_tran_date)
all_data['transaction_date'] = all_data['transaction_year_month'].astype(int).astype(str) + all_data['transaction_day'].astype(str)
all_data['transaction_date'] = pd.to_datetime(all_data['transaction_date'])
all_data = all_data.sort_values('transaction_date').reset_index(drop=True)
display(all_data)
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion train_test  \
# 0                   180000.0     16                2005      train
# 1                    68000.0      5                2008      train
# 2                    72600.0      8                1999      train
# 3                   155000.0      5                1983      train
# 4                    27000.0     20                2004      train
# ...                      ...    ...                 ...        ...
# 6178                     NaN     16                2004       test
# 6179                     NaN     12                1985       test
# 6180                     NaN      1                1984       test
# 6181                     NaN     12                1984       test
# 6182                     NaN      9                1999       test
#
#      transaction_date
# 0          2014-01-02
# 1          2014-01-02
# 2          2014-01-04
# 3          2014-01-04
# 4          2014-01-04
# ...               ...
# 6178       2023-06-23
# 6179       2023-06-23
# 6180       2023-06-24
# 6181       2023-06-24
# 6182       2023-06-30
#
# [6183 rows x 12 columns]

# %%
melong = pd.read_csv('/project/datacamp/team3/t3user1/규모별_매매가격지수.csv',encoding = 'cp949')
melong.tail(30)
# Out:
#      지역별 주택유형별 주택규모별       시점    데이터
# 572  수도권   아파트   규모6  2020.07   90.6
# 573  수도권   아파트   규모6  2020.08   91.1
# 574  수도권   아파트   규모6  2020.09   91.8
# 575  수도권   아파트   규모6  2020.10   92.4
# 576  수도권   아파트   규모6  2020.11   93.1
# 577  수도권   아파트   규모6  2020.12   94.0
# 578  수도권   아파트   규모6  2021.01   94.9
# 579  수도권   아파트   규모6  2021.02   96.0
# 580  수도권   아파트   규모6  2021.03   96.7
# 581  수도권   아파트   규모6  2021.04   97.5
# 582  수도권   아파트   규모6  2021.05   98.3
# 583  수도권   아파트   규모6  2021.06  100.0
# 584  수도권   아파트   규모6  2021.07  101.0
# 585  수도권   아파트   규모6  2021.08  102.2
# 586  수도권   아파트   규모6  2021.09  103.4
# 587  수도권   아파트   규모6  2021.10  104.6
# 588  수도권   아파트   규모6  2021.11  105.5
# 589  수도권   아파트   규모6  2021.12  105.9
# 590  수도권   아파트   규모6  2022.01  106.0
# 591  수도권   아파트   규모6  2022.02  106.1
# 592  수도권   아파트   규모6  2022.03  106.1
# 593  수도권   아파트   규모6  2022.04  106.2
# 594  수도권   아파트   규모6  2022.05  106.3
# 595  수도권   아파트   규모6  2022.06  106.3
# 596  수도권   아파트   규모6  2022.07  106.2
# 597  수도권   아파트   규모6  2022.08  106.1
# 598  수도권   아파트   규모6  2022.09  105.6
# 599  수도권   아파트   규모6  2022.10  104.8
# 600  수도권   아파트   규모6  2022.11  103.4
# 601  수도권   아파트   규모6  2022.12  101.2

# %% [markdown]
# # 새로운 칼럼 가져오기

# %% [markdown]
# ## 전국 아파트 매매 동향 가져오기 및 데이터 확인

# %%
korea_price = pd.read_csv('/project/datacamp/team3/t3user1/newapart.csv',encoding = 'cp949')
korea_price
# Out:
#     주택유형별  지역별 주택규모별       시점   데이터
# 0     아파트  수도권   규모1  2017.11  90.0
# 1     아파트  수도권   규모1  2017.12  90.2
# 2     아파트  수도권   규모1  2018.01  90.4
# 3     아파트  수도권   규모1  2018.02  90.7
# 4     아파트  수도권   규모1  2018.03  90.9
# ..    ...  ...   ...      ...   ...
# 633   아파트  수도권   규모6  2023.02  98.8
# 634   아파트  수도권   규모6  2023.03  97.9
# 635   아파트  수도권   규모6  2023.04  97.5
# 636   아파트  수도권   규모6  2023.05  97.4
# 637   아파트  수도권   규모6  2023.06  97.5
#
# [638 rows x 5 columns]

# %%
korea_price['주택규모별'] = korea_price['주택규모별'].str.replace('규모', '')
korea_price
# Out:
#     주택유형별  지역별 주택규모별       시점   데이터
# 0     아파트  수도권     1  2017.11  90.0
# 1     아파트  수도권     1  2017.12  90.2
# 2     아파트  수도권     1  2018.01  90.4
# 3     아파트  수도권     1  2018.02  90.7
# 4     아파트  수도권     1  2018.03  90.9
# ..    ...  ...   ...      ...   ...
# 633   아파트  수도권     6  2023.02  98.8
# 634   아파트  수도권     6  2023.03  97.9
# 635   아파트  수도권     6  2023.04  97.5
# 636   아파트  수도권     6  2023.05  97.4
# 637   아파트  수도권     6  2023.06  97.5
#
# [638 rows x 5 columns]

# %% [markdown]
# ## korea_price 날짜 처리

# %%
korea_price_copy=korea_price
korea_price_copy["연도"]=0
korea_price_copy["월"]=0

# %%
for i,x in enumerate(korea_price['시점']):
    korea_price_copy.iloc[i,-2]=int(str(x).split('.')[0])
    
    if len(str(x).split('.')[1]) == 1 :
        korea_price_copy.iloc[i,-1]=10
    else:
        korea_price_copy.iloc[i,-1]=int(str(x).split('.')[1])

        

#시점 열 읽어와서 .기준으로 스플릿 하고 앞에껀 그대로 '연도' 열에 넣고 뒤에껀 10월은 1이되기 때문에 (1월은 01) 길이가 1인 것은 10월로 나머지는 그대로 '월' 열에넣기

# %%
korea_price=korea_price_copy

# %%
korea_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638 entries, 0 to 637
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주택유형별   638 non-null    object
#  1   지역별     638 non-null    object
#  2   주택규모별   638 non-null    object
#  3   시점      638 non-null    float64
#  4   데이터     638 non-null    float64
#  5   연도      638 non-null    int64
#  6   월       638 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 35.0+ KB

# %% [markdown]
# ## all_data 에 규모 데이터 추가하기

# %%
def size(x):
    if x <= 40 :
        return '1'
    elif x <= 60 :
        return '2'
    elif x <= 85 :
        return '3'
    elif x <= 102 :
        return '4'
    elif x <= 135 :
        return '5'
    else :
        return '6'
    
    
all_data['주택규모별'] = all_data['exclusive_use_area'].apply(size)
all_data
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion train_test  \
# 0                   180000.0     16                2005      train
# 1                    68000.0      5                2008      train
# 2                    72600.0      8                1999      train
# 3                   155000.0      5                1983      train
# 4                    27000.0     20                2004      train
# ...                      ...    ...                 ...        ...
# 6178                     NaN     16                2004       test
# 6179                     NaN     12                1985       test
# 6180                     NaN      1                1984       test
# 6181                     NaN     12                1984       test
# 6182                     NaN      9                1999       test
#
#      transaction_date 주택규모별
# 0          2014-01-02     6
# 1          2014-01-02     3
# 2          2014-01-04     3
# 3          2014-01-04     6
# 4          2014-01-04     1
# ...               ...   ...
# 6178       2023-06-23     6
# 6179       2023-06-23     5
# 6180       2023-06-24     3
# 6181       2023-06-24     3
# 6182       2023-06-30     3
#
# [6183 rows x 13 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6183 entries, 0 to 6182
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      6183 non-null   object
#  1   sigungu                 6183 non-null   object
#  2   jibun                   6183 non-null   object
#  3   apt_name                6183 non-null   object
#  4   exclusive_use_area      6183 non-null   float64
#  5   transaction_year_month  6183 non-null   int64
#  6   transaction_day         6183 non-null   object
#  7   transaction_real_price  5987 non-null   float64
#  8   floor                   6183 non-null   int64
#  9   year_of_completion      6183 non-null   int64
#  10  train_test              6183 non-null   object
#  11  transaction_date        6183 non-null   datetime64[ns]
#  12  주택규모별                   6183 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(7)
# memory usage: 628.1+ KB

# %%
# 데이터 연도와 월 따로 저장

all_data['연도'] = all_data['transaction_date'].dt.year
all_data['월'] = all_data['transaction_date'].dt.month

# %%
korea_price
# Out:
#     주택유형별  지역별 주택규모별       시점   데이터    연도   월
# 0     아파트  수도권     1  2017.11  90.0  2017  11
# 1     아파트  수도권     1  2017.12  90.2  2017  12
# 2     아파트  수도권     1  2018.01  90.4  2018   1
# 3     아파트  수도권     1  2018.02  90.7  2018   2
# 4     아파트  수도권     1  2018.03  90.9  2018   3
# ..    ...  ...   ...      ...   ...   ...  ..
# 633   아파트  수도권     6  2023.02  98.8  2023   2
# 634   아파트  수도권     6  2023.03  97.9  2023   3
# 635   아파트  수도권     6  2023.04  97.5  2023   4
# 636   아파트  수도권     6  2023.05  97.4  2023   5
# 637   아파트  수도권     6  2023.06  97.5  2023   6
#
# [638 rows x 7 columns]

# %% [markdown]
# ## all_data 매매지수 칼럼 추가

# %%
all_data
all_data["매매지수"]=0

# %%
for i,x in enumerate(all_data[['주택규모별','연도','월']].values):
    for ii, y in enumerate(korea_price[['주택규모별','연도','월']].values):
        if (x[0]==y[0]) and (x[1]==y[1]) and (x[2]==y[2]):
             all_data.iloc[i,-1]=korea_price.iloc[ii,-3]
        else:
            pass

# %%
all_data
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion train_test  \
# 0                   180000.0     16                2005      train
# 1                    68000.0      5                2008      train
# 2                    72600.0      8                1999      train
# 3                   155000.0      5                1983      train
# 4                    27000.0     20                2004      train
# ...                      ...    ...                 ...        ...
# 6178                     NaN     16                2004       test
# 6179                     NaN     12                1985       test
# 6180                     NaN      1                1984       test
# 6181                     NaN     12                1984       test
# 6182                     NaN      9                1999       test
#
#      transaction_date 주택규모별    연도  월  매매지수
# 0          2014-01-02     6  2014  1  79.3
# 1          2014-01-02     3  2014  1  70.5
# 2          2014-01-04     3  2014  1  70.5
# 3          2014-01-04     6  2014  1  79.3
# 4          2014-01-04     1  2014  1   0.0
# ...               ...   ...   ... ..   ...
# 6178       2023-06-23     6  2023  6  97.5
# 6179       2023-06-23     5  2023  6  94.2
# 6180       2023-06-24     3  2023  6  90.0
# 6181       2023-06-24     3  2023  6  90.0
# 6182       2023-06-30     3  2023  6  90.0
#
# [6183 rows x 16 columns]

# %%
all_data.drop(['연도','월'], axis=1)
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion train_test  \
# 0                   180000.0     16                2005      train
# 1                    68000.0      5                2008      train
# 2                    72600.0      8                1999      train
# 3                   155000.0      5                1983      train
# 4                    27000.0     20                2004      train
# ...                      ...    ...                 ...        ...
# 6178                     NaN     16                2004       test
# 6179                     NaN     12                1985       test
# 6180                     NaN      1                1984       test
# 6181                     NaN     12                1984       test
# 6182                     NaN      9                1999       test
#
#      transaction_date 주택규모별  매매지수
# 0          2014-01-02     6  79.3
# 1          2014-01-02     3  70.5
# 2          2014-01-04     3  70.5
# 3          2014-01-04     6  79.3
# 4          2014-01-04     1   0.0
# ...               ...   ...   ...
# 6178       2023-06-23     6  97.5
# 6179       2023-06-23     5  94.2
# 6180       2023-06-24     3  90.0
# 6181       2023-06-24     3  90.0
# 6182       2023-06-30     3  90.0
#
# [6183 rows x 14 columns]

# %% [markdown]
# ## all_data 매매지수 칼럼 결측치 처리

# %%
mean_value = round(all_data[all_data['매매지수'] != 0.0]['매매지수'].mean(),1)
all_data['매매지수'] = all_data['매매지수'].replace(0.0,mean_value)

# %%
all_data[(all_data['주택규모별']=='규모1')&(all_data['연도']==2014)]
# Out:
# Empty DataFrame
# Columns: [id, sigungu, jibun, apt_name, exclusive_use_area, transaction_year_month, transaction_day, transaction_real_price, floor, year_of_completion, train_test, transaction_date, 주택규모별, 연도, 월, 매매지수]
# Index: []

# %%
train2 = all_data[all_data['train_test']=='train']
train3=train2.drop(['id','apt_name','sigungu','jibun','train_test','주택규모별'], axis=1)

# %%
grouped_df = train2.groupby('주택규모별')

# %%
all_data
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion train_test  \
# 0                   180000.0     16                2005      train
# 1                    68000.0      5                2008      train
# 2                    72600.0      8                1999      train
# 3                   155000.0      5                1983      train
# 4                    27000.0     20                2004      train
# ...                      ...    ...                 ...        ...
# 6178                     NaN     16                2004       test
# 6179                     NaN     12                1985       test
# 6180                     NaN      1                1984       test
# 6181                     NaN     12                1984       test
# 6182                     NaN      9                1999       test
#
#      transaction_date 주택규모별    연도  월  매매지수
# 0          2014-01-02     6  2014  1  79.3
# 1          2014-01-02     3  2014  1  70.5
# 2          2014-01-04     3  2014  1  70.5
# 3          2014-01-04     6  2014  1  79.3
# 4          2014-01-04     1  2014  1  80.8
# ...               ...   ...   ... ..   ...
# 6178       2023-06-23     6  2023  6  97.5
# 6179       2023-06-23     5  2023  6  94.2
# 6180       2023-06-24     3  2023  6  90.0
# 6181       2023-06-24     3  2023  6  90.0
# 6182       2023-06-30     3  2023  6  90.0
#
# [6183 rows x 16 columns]

# %% [markdown]
# ## 인구밀도 넣기

# %%
mm = pd.read_csv('/project/datacamp/team3/t3user2/과제/인구밀도.csv', encoding='utf-8')
mm.index = mm['시점']
mm.columns = mm.iloc[1]
mm = mm.drop(['시점'], axis=0)

# %%
mm['대치동'] = 0
for i in range(len(mm)):
    mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# Out:
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])
# /tmp/ipykernel_613906/1605022573.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm['대치동'][i] = int(mm['대치1동'][i]) + int(mm['대치2동'][i]) + int(mm['대치4동'][i])

# %%
all_data
all_data["인구밀도"]=0

# %%
for i,x in enumerate(all_data['연도']):
    for ii,y in enumerate(mm['시점']):
        if x == int(y) :
            all_data.iloc[i,-1] = mm.iloc[ii,-1]
        else:
            pass

# %%
daechi_1 = ['선경1차(1동-7동)', '선경3차', '선경2차(8동-12동)', '개포우성1', '개포우성2',
           '동부센트레빌', '래미안대치팰리스', '대치SKVIEW', '노빌리티빌리지', '대치삼성',
           '롯데캐슬리베', '대치하나빌', '롯데캐슬', '미도맨션3차', '삼성2차', '삼성3차', 
           '청암빌라트']

daechi_2 = ['우정에쉐르', '대치동우정에쉐르1', '대치동우정에쉐르2(890-42)', '화인하이빌', 
            '대치아이파크', '대치우성아파트1동,2동,3동,5동,6동,7동', '대치주성', 
           '대치현대', '대치효성', '래미안대치하이스턴', '상지리츠빌카일룸(1009-4)', '은마', 
           '풍림아이원3차(1007-1)', '풍림아이원4차(1007-2)', '하이캐슬', '하이캐슬102동', 
           '한보미도맨션1', '한보미도맨션2', '한양팰리스', '해암프리존', '현대1', '세영팔레스타운', 
           '(977-)']

daechi_4 = ['대우아이빌멤버스(891-26)', '대우아이빌명문가(891-23)', '대치동우정에쉐르1', 
           '대치동우정에쉐르2(890-42)', '대치타워', '대치한신휴플러스', '동민맥스빌A동', 
           '동민맥스빌B동', '동양', '메트로', '삼환SOGOOD', '선릉역풍림아이원레몬', '세연파크뷰', 
           '스카이써밋아파트', '쌍용대치2', '쌍용대치아파트1동,2동,3동,5동,6동', '아름빌(889-74)', 
           '월드빌', '청원', '테헤란로대우아이빌(891-6)', '포스코더샵', '풍림아이원1차101동(910-3)', 
           '풍림아이원1차103동(910-5)', '풍림아이원2차201동', '풍림아이원2차202동', '한티(933-0)', 
           '한티(933-35)', '현대썬앤빌테헤란', '신성미소시티', '풍림아이원아파트']

# %%
def daechi(x):
    if x in daechi_1:
        return 'daechi_1'
    elif x in daechi_2:
        return 'daechi_2'
    else:
        return 'daechi_4'

# %%
all_data['daechi'] = all_data['apt_name'].apply(daechi)

# %%
all_data
all_data["동별인구밀도"]=0

# %%
for i,x in enumerate(all_data[['연도','daechi']].values):
    for ii, y in enumerate(mm['시점'].values):
        if x[0]==int(y):
            if (x[1]=='daechi_1'):
                all_data.iloc[i,-1]=mm.iloc[ii,-4]
            elif (x[1]=='daechi_4'):
                all_data.iloc[i,-1]=mm.iloc[ii,-3]
            else:
                all_data.iloc[i,-1]=mm.iloc[ii,-2]
        elif x[0]==2023:
            if (x[1]=='daechi_1'):
                all_data.iloc[i,-1]=mm[mm['시점']=='2022'].iloc[0,-4]
            elif (x[1]=='daechi_4'):
                all_data.iloc[i,-1]=mm[mm['시점']=='2022'].iloc[0,-3]
            else:
                all_data.iloc[i,-1]=mm[mm['시점']=='2022'].iloc[0,-2]
all_data['동별인구밀도'] = all_data['동별인구밀도'].astype(int)

# %% [markdown]
# ## 아파트 군집 초등학교 거리

# %%
all2= all_data
all2['element school distance(m)']=0
all2.head()
# Out:
#            id        sigungu   jibun          apt_name  exclusive_use_area  \
# 0  TRAIN_0320  서울특별시 강남구 대치동     670            동부센트레빌              145.83
# 1  TRAIN_0699  서울특별시 강남구 대치동  986-14              하이캐슬               84.06
# 2  TRAIN_0311  서울특별시 강남구 대치동   988-4              대치효성               84.91
# 3  TRAIN_0705  서울특별시 강남구 대치동     511           한보미도맨션1              161.36
# 4  TRAIN_0660  서울특별시 강남구 대치동   891-6  테헤란로대우아이빌(891-6)               33.11
#
#    transaction_year_month transaction_day  transaction_real_price  floor  \
# 0                  201401              02                180000.0     16
# 1                  201401              02                 68000.0      5
# 2                  201401              04                 72600.0      8
# 3                  201401              04                155000.0      5
# 4                  201401              04                 27000.0     20
#
#    year_of_completion train_test transaction_date 주택규모별    연도  월  매매지수   인구밀도  \
# 0                2005      train       2014-01-02     6  2014  1  79.3  76948
# 1                2008      train       2014-01-02     3  2014  1  70.5  76948
# 2                1999      train       2014-01-04     3  2014  1  70.5  76948
# 3                1983      train       2014-01-04     6  2014  1  79.3  76948
# 4                2004      train       2014-01-04     1  2014  1  80.8  76948
#
#      daechi  동별인구밀도  element school distance(m)
# 0  daechi_1   25068                           0
# 1  daechi_2   21559                           0
# 2  daechi_2   21559                           0
# 3  daechi_2   21559                           0
# 4  daechi_4   30321                           0

# %%
# 아파트 별 초등학교 거리
esd={'503' : 705, 
      '500' : 400,
      '612' : 400,
      '891-26': 560, 
      '891-23': 590, 
      '891-28': 590, 
      '890-42': 750,
      '1014-3': 460,
      '888':250 , 
      '63':600,
      '1015-6':425,
      '907-2':200,
      '974':400,
      '988-4':460,
      '938-11':200,
      '670':165,
      '920-32': 155,
      '985':320,
      '893':630,
      '1025':370,
      '901-51':395,
      '1016-2': 500,
       '938-16':240,
      '1009-4':460,
      '506':100,
      '602':320,
      '890-49':415,
      '890-54':400,
      '929-8':340,
      '975-20':350,
      '904-10':385,
      '65':700,
      '66':700, 
      '889-74':265,
      '316':330,
      '891-6':650,
      '902':590,
       '910-3':225,
      '910-7':195,
      '1007-1':260,
      '1007-2':255,
      '910-4':220,
      '986-14':370,
      '986':380,
       '511':250,
      '933-35':240,
      '992':450,
      '950-5':300,
      '962-20':380,
      '914-8':365,
      '938-13':205,
       '1027':380,
      '601-1':260,
      '915-13':360,
      '950':355,
      '934-1':160,
      '910-5':250,
      '910-6':215,
       '941-13':450,
      '983-1':135,
      '950-3':325,
      '1017-1':500,
      '1029':400,
      '1014-1':365,
      '933':230,
       '894':530,
      '650': 320,
       '977': 256 }

# %%
all_data=all2
all_data
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion train_test  \
# 0                   180000.0     16                2005      train
# 1                    68000.0      5                2008      train
# 2                    72600.0      8                1999      train
# 3                   155000.0      5                1983      train
# 4                    27000.0     20                2004      train
# ...                      ...    ...                 ...        ...
# 6178                     NaN     16                2004       test
# 6179                     NaN     12                1985       test
# 6180                     NaN      1                1984       test
# 6181                     NaN     12                1984       test
# 6182                     NaN      9                1999       test
#
#      transaction_date 주택규모별    연도  월  매매지수   인구밀도    daechi  동별인구밀도  \
# 0          2014-01-02     6  2014  1  79.3  76948  daechi_1   25068
# 1          2014-01-02     3  2014  1  70.5  76948  daechi_2   21559
# 2          2014-01-04     3  2014  1  70.5  76948  daechi_2   21559
# 3          2014-01-04     6  2014  1  79.3  76948  daechi_2   21559
# 4          2014-01-04     1  2014  1  80.8  76948  daechi_4   30321
# ...               ...   ...   ... ..   ...    ...       ...     ...
# 6178       2023-06-23     6  2023  6  97.5      0  daechi_4   26700
# 6179       2023-06-23     5  2023  6  94.2      0  daechi_2   18549
# 6180       2023-06-24     3  2023  6  90.0      0  daechi_1   30185
# 6181       2023-06-24     3  2023  6  90.0      0  daechi_2   18549
# 6182       2023-06-30     3  2023  6  90.0      0  daechi_2   18549
#
#       element school distance(m)
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 6178                           0
# 6179                           0
# 6180                           0
# 6181                           0
# 6182                           0
#
# [6183 rows x 20 columns]

# %%
#
for i,ii in enumerate(all2.loc[:,'jibun']):
    for xx,yy in esd.items():
        if ii == xx:
            all2.iloc[i,-1]=int(yy)
        else:
            pass

# %%
from sklearn.cluster import KMeans
import numpy as np

# 아파트 별로 가격 평균값 구하기
train = all_data[all_data['train_test'] == 'train']

train['transaction_real_price']=train['transaction_real_price'].replace('.', '').astype('int')
data = train[['element school distance(m)', 'transaction_real_price']]
train
# Out:
# /tmp/ipykernel_613906/143381997.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['transaction_real_price']=train['transaction_real_price'].replace('.', '').astype('int')
#               id        sigungu   jibun          apt_name  exclusive_use_area  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670            동부센트레빌              145.83
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14              하이캐슬               84.06
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4              대치효성               84.91
# 3     TRAIN_0705  서울특별시 강남구 대치동     511           한보미도맨션1              161.36
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6  테헤란로대우아이빌(891-6)               33.11
# ...          ...            ...     ...               ...                 ...
# 5982  TRAIN_5956  서울특별시 강남구 대치동     316                은마               84.43
# 5983  TRAIN_5957  서울특별시 강남구 대치동     316                은마               76.79
# 5984  TRAIN_5958  서울특별시 강남구 대치동     316                은마               76.79
# 5985  TRAIN_5975  서울특별시 강남구 대치동     902             포스코더샵              139.54
# 5986  TRAIN_5959  서울특별시 강남구 대치동     316                은마               76.79
#
#       transaction_year_month transaction_day  transaction_real_price  floor  \
# 0                     201401              02                  180000     16
# 1                     201401              02                   68000      5
# 2                     201401              04                   72600      8
# 3                     201401              04                  155000      5
# 4                     201401              04                   27000     20
# ...                      ...             ...                     ...    ...
# 5982                  202212              26                  231000      8
# 5983                  202212              28                  182000      8
# 5984                  202212              30                  184500      2
# 5985                  202212              30                  290000     11
# 5986                  202212              31                  184000      2
#
#       year_of_completion train_test transaction_date 주택규모별    연도   월   매매지수  \
# 0                   2005      train       2014-01-02     6  2014   1   79.3
# 1                   2008      train       2014-01-02     3  2014   1   70.5
# 2                   1999      train       2014-01-04     3  2014   1   70.5
# 3                   1983      train       2014-01-04     6  2014   1   79.3
# 4                   2004      train       2014-01-04     1  2014   1   80.8
# ...                  ...        ...              ...   ...   ...  ..    ...
# 5982                1979      train       2022-12-26     3  2022  12   96.0
# 5983                1979      train       2022-12-28     3  2022  12   96.0
# 5984                1979      train       2022-12-30     3  2022  12   96.0
# 5985                2004      train       2022-12-30     6  2022  12  101.2
# 5986                1979      train       2022-12-31     3  2022  12   96.0
#
#        인구밀도    daechi  동별인구밀도  element school distance(m)
# 0     76948  daechi_1   25068                         165
# 1     76948  daechi_2   21559                         370
# 2     76948  daechi_2   21559                         460
# 3     76948  daechi_2   21559                         250
# 4     76948  daechi_4   30321                         650
# ...     ...       ...     ...                         ...
# 5982  75434  daechi_2   18549                         330
# 5983  75434  daechi_2   18549                         330
# 5984  75434  daechi_2   18549                         330
# 5985  75434  daechi_4   26700                         590
# 5986  75434  daechi_2   18549                         330
#
# [5987 rows x 20 columns]

# %%
data
# Out:
#       element school distance(m)  transaction_real_price
# 0                            165                  180000
# 1                            370                   68000
# 2                            460                   72600
# 3                            250                  155000
# 4                            650                   27000
# ...                          ...                     ...
# 5982                         330                  231000
# 5983                         330                  182000
# 5984                         330                  184500
# 5985                         590                  290000
# 5986                         330                  184000
#
# [5987 rows x 2 columns]

# %%
data = data.groupby('element school distance(m)').mean()
arr = data['transaction_real_price'].to_numpy().reshape(-1, 1)



# 가격을 기준으로 초등학교 거리 군집화
k = 7  
kmeans = KMeans(n_clusters=k, n_init=10)
kmeans.fit(arr)

# 가격을 기준으로 군집의 순서를 정렬하기 위해 인덱스를 추출
sort_order = np.argsort(kmeans.cluster_centers_.flatten())

# 군집화 결과를 가격 순서대로 재할당
labels = np.zeros_like(kmeans.labels_)
for i, cluster in enumerate(sort_order):
    labels[kmeans.labels_ == cluster] = i

# 군집화 결과와 가격을 데이터에 추가
data['cluster'] = labels
data = data.reset_index()
data = data[['element school distance(m)', 'cluster']]
data
# Out:
#     element school distance(m)  cluster
# 0                          100        6
# 1                          135        3
# 2                          155        1
# 3                          160        1
# 4                          165        6
# 5                          195        2
# 6                          200        2
# 7                          205        2
# 8                          215        2
# 9                          220        2
# 10                         225        2
# 11                         230        2
# 12                         240        2
# 13                         250        5
# 14                         255        3
# 15                         260        3
# 16                         265        0
# 17                         300        1
# 18                         320        4
# 19                         325        1
# 20                         330        4
# 21                         340        2
# 22                         350        2
# 23                         355        2
# 24                         360        1
# 25                         365        3
# 26                         370        4
# 27                         380        6
# 28                         385        2
# 29                         395        1
# 30                         400        4
# 31                         415        0
# 32                         425        3
# 33                         450        2
# 34                         460        3
# 35                         500        4
# 36                         530        1
# 37                         560        0
# 38                         590        2
# 39                         600        4
# 40                         630        3
# 41                         650        0
# 42                         700        5
# 43                         705        6
# 44                         750        1

# %%
all_data = pd.merge(all_data, data, how='left', left_on='element school distance(m)', right_on='element school distance(m)')

cluster_mode = all_data.loc[all_data['train_test'] == 'train', 'cluster'].mode()
all_data['cluster'] = all_data['cluster'].fillna(cluster_mode)

all_data['cluster'].value_counts()
# Out:
# cluster
# 4.0    2342
# 6.0    1298
# 5.0    1169
# 3.0     555
# 2.0     480
# 0.0     281
# 1.0      56
# Name: count, dtype: int64

# %%
for ii,x in enumerate(all_data[['element school distance(m)','train_test']].values):
    if x[1]=='test':
        all_data.iloc[ii,-5]=np.nan
    else:
        pass

# %%
all_data[all_data['train_test']=='test']['cluster'].head(2)

apt_distance_mode = all_data.loc[all_data['train_test'] == 'train', 'cluster'].mode()





#fillna로 채워지지 않는 (977-) 아파트에 대해 apt_name_mode값 직접 입력
for i,x in enumerate(all_data['id'].values):
    if (x=='TEST_0000') or (x == 'TEST_0001') :
        all_data.iloc[i,-1]=apt_distance_mode

# %%
all_data[all_data['apt_name']=='(977-)'][['cluster']]
# Out:
#       cluster
# 6069      4.0
# 6073      4.0

# %% [markdown]
# ## 금리데이터 추가

# %%
# !pip install tqdm
from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (4.65.0)

# %%
def make_date(row):
    month_day = row['월일'].replace('월 ', '-')
    month_day = month_day.replace('일', '')
    date = str(row['연도'])+ '-' + month_day
    return date

interest_rate['날짜'] = interest_rate.apply(lambda x: make_date(x), axis=1)
interest_rate['날짜'] = pd.to_datetime(interest_rate['날짜'])

for idx, row in tqdm(all_data.iterrows(), total = all_data.shape[0]):
    date = row['transaction_date']
    rate = interest_rate[interest_rate['날짜'] <= date].iloc[0]['금리']
    all_data.loc[idx, 'interest_rate'] = rate
# Out:
# 100%|████████████████████████████████████████| 6183/6183 [00:01<00:00, 4848.71it/s]

# %% [markdown]
# ## 최근 거래된 가격 구하기

# %%
from tqdm import tqdm
from datetime import datetime

all_data['apartment_id'] = all_data.groupby(['sigungu', 'apt_name']).ngroup()

def get_recent_price(idx, all_data):
    temp_df = all_data.loc[:idx]
    temp_df = temp_df[
        (temp_df['transaction_date'] < row['transaction_date']) &
        (temp_df['주택규모별'] == row['주택규모별'])
    ]
    if len(temp_df) == 0:
        temp_df = all_data[
            (all_data['transaction_date'] < datetime.strptime('2016-01-01', "%Y-%m-%d")) &
            (all_data['주택규모별'] == row['주택규모별'])
        ]
    
    # 아파트 아이디 같은것 찾기
    recent_price = temp_df[(temp_df['apartment_id'] == row['apartment_id'])]
    if len(recent_price) == 0:
        recent_price = temp_df[(temp_df['sigungu'] == row['sigungu'])]
        recent_price = recent_price.iloc[-1]['transaction_real_price']
    else:
        recent_price = recent_price.iloc[-1]['transaction_real_price']  
    
    if recent_price is None:
        recent_price = temp_df['transaction_real_price'].mean() # 2019년 전체평균

    return recent_price

for idx, row in tqdm(all_data.iterrows(), total = all_data.shape[0]):
    if row['train_test'] == 'test':  
        continue
    all_data.loc[idx, 'recent_price'] = get_recent_price(idx, all_data)
# Out:
# 100%|████████████████████████████████████████| 6183/6183 [00:04<00:00, 1360.45it/s]

# %% [markdown]
# ## 주택규모별 가격 클러스터링

# %%
from sklearn.cluster import KMeans
import numpy as np

# 아파트 별로 가격 평균값 구하기
data = all_data[all_data['train_test'] == 'train']
data
data['transaction_real_price']=data['transaction_real_price'].replace('.', '').astype('int')
data = data[['주택규모별','transaction_real_price']]
data
# Out:
# /tmp/ipykernel_613906/105924531.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['transaction_real_price']=data['transaction_real_price'].replace('.', '').astype('int')
#      주택규모별  transaction_real_price
# 0        6                  180000
# 1        3                   68000
# 2        3                   72600
# 3        6                  155000
# 4        1                   27000
# ...    ...                     ...
# 5982     3                  231000
# 5983     3                  182000
# 5984     3                  184500
# 5985     6                  290000
# 5986     3                  184000
#
# [5987 rows x 2 columns]

# %%
data = data.groupby(['주택규모별']).mean()
arr = data['transaction_real_price'].to_numpy().reshape(-1, 1)

data
# 가격을 기준으로 초등학교 거리 군집화
k = 6
kmeans = KMeans(n_clusters=k, n_init=10)
kmeans.fit(arr)

# 가격을 기준으로 군집의 순서를 정렬하기 위해 인덱스를 추출
sort_order = np.argsort(kmeans.cluster_centers_.flatten())

# 군집화 결과를 가격 순서대로 재할당
labels = np.zeros_like(kmeans.labels_)
for i, cluster in enumerate(sort_order):
    labels[kmeans.labels_ == cluster] = i

# 군집화 결과와 가격을 데이터에 추가
data['size_sale'] = labels
data = data.reset_index()
data = data[['주택규모별', 'size_sale']]
data
# Out:
#   주택규모별  size_sale
# 0     1          0
# 1     2          1
# 2     3          2
# 3     4          3
# 4     5          4
# 5     6          5

# %%
all_data = pd.merge(all_data, data, how='left', left_on='주택규모별', right_on='주택규모별')

cluster_mode = all_data.loc[all_data['train_test'] == 'train', 'cluster'].mode()
all_data['size_sale'] = all_data['size_sale'].fillna(cluster_mode)

all_data['size_sale'].value_counts()
# Out:
# size_sale
# 2    2829
# 4    1321
# 5     820
# 1     479
# 3     436
# 0     298
# Name: count, dtype: int64

# %% [markdown]
# ## 증감률

# %%
percent = pd.read_csv('percent1.csv',encoding = 'cp949')
p =percent.drop(['시군구별(1)','시군구별(2)'], axis = 1).transpose()
percent = p.drop(0,axis = 1)
percent.index = percent.index.str.replace('.','')
percent.rename(columns={1: '증감률'}, inplace = True)
percent = percent['증감률'].astype(float)
percent= percent.to_frame()

#nan 없애기
per = percent[percent.index.str.contains('2023')]
a = per['증감률'].mean()

new_index = '202306'
new_row = {'증감률': a}
percent.loc[new_index] = new_row


for indeval_xue, percent_value in percent.iterrows():
    if int(indeval_xue) in all_data['transaction_year_month'].values:
        all_data.loc[all_data['transaction_year_month'] == int(indeval_xue), 'percent'] = percent_value[0]

# %% [markdown]
# ## 주택규모별 층별 평균 가격

# %%
import numpy as np

# 아파트 별로 가격 평균값 구하기
data = all_data[all_data['train_test'] == 'train']
data
data['transaction_real_price']=data['transaction_real_price'].replace('.', '').astype('int')
data = data[['주택규모별','floor','transaction_real_price']]
data
# Out:
# /tmp/ipykernel_613906/1396988779.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['transaction_real_price']=data['transaction_real_price'].replace('.', '').astype('int')
#      주택규모별  floor  transaction_real_price
# 0        6     16                  180000
# 1        3      5                   68000
# 2        3      8                   72600
# 3        6      5                  155000
# 4        1     20                   27000
# ...    ...    ...                     ...
# 5982     3      8                  231000
# 5983     3      8                  182000
# 5984     3      2                  184500
# 5985     6     11                  290000
# 5986     3      2                  184000
#
# [5987 rows x 3 columns]

# %%
data['주택규모별floor'] = data['주택규모별'].astype('str') + data['floor'].astype('str')
size_floor_price = data[['transaction_real_price']].groupby(data['주택규모별floor']).mean().reset_index()
size_floor_price
# Out:
#     주택규모별floor  transaction_real_price
# 0          110            27883.870968
# 1          111            25237.878788
# 2          112            26636.000000
# 3          113            26409.230769
# 4          114            27285.294118
# ..         ...                     ...
# 173         65           222776.956522
# 174         66           212302.210526
# 175         67           209477.333333
# 176         68           255407.894737
# 177         69           226970.400000
#
# [178 rows x 2 columns]

# %%
all_data['주택규모별floor'] = all_data['주택규모별'].astype('str') + all_data['floor'].astype('str')
all_data['size_floor_price'] = 0

# %%
for i,x in enumerate(all_data[['주택규모별floor','size_floor_price']].values):
    for ii, y in enumerate(size_floor_price[['주택규모별floor','transaction_real_price']].values):
        if x[0]==y[0] :
             all_data.iloc[i,-1]=size_floor_price.iloc[ii,-1]
        else:
            pass

# %%
all_data
# Out:
#               id        sigungu   jibun                  apt_name  \
# 0     TRAIN_0320  서울특별시 강남구 대치동     670                    동부센트레빌
# 1     TRAIN_0699  서울특별시 강남구 대치동  986-14                      하이캐슬
# 2     TRAIN_0311  서울특별시 강남구 대치동   988-4                      대치효성
# 3     TRAIN_0705  서울특별시 강남구 대치동     511                   한보미도맨션1
# 4     TRAIN_0660  서울특별시 강남구 대치동   891-6          테헤란로대우아이빌(891-6)
# ...          ...            ...     ...                       ...
# 6178   TEST_0161  서울특별시 강남구 대치동     902                     포스코더샵
# 6179   TEST_0194  서울특별시 강남구 대치동     511                   한보미도맨션2
# 6180   TEST_0013  서울특별시 강남구 대치동     500                     개포우성2
# 6181   TEST_0045  서울특별시 강남구 대치동      63  대치우성아파트1동,2동,3동,5동,6동,7동
# 6182   TEST_0050  서울특별시 강남구 대치동   988-4                      대치효성
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 0                 145.83                  201401              02
# 1                  84.06                  201401              02
# 2                  84.91                  201401              04
# 3                 161.36                  201401              04
# 4                  33.11                  201401              04
# ...                  ...                     ...             ...
# 6178              139.54                  202306              23
# 6179              126.33                  202306              23
# 6180               84.69                  202306              24
# 6181               84.69                  202306              24
# 6182               84.91                  202306              30
#
#       transaction_real_price  floor  year_of_completion  ... 동별인구밀도  \
# 0                   180000.0     16                2005  ...  25068
# 1                    68000.0      5                2008  ...  21559
# 2                    72600.0      8                1999  ...  21559
# 3                   155000.0      5                1983  ...  21559
# 4                    27000.0     20                2004  ...  30321
# ...                      ...    ...                 ...  ...    ...
# 6178                     NaN     16                2004  ...  26700
# 6179                     NaN     12                1985  ...  18549
# 6180                     NaN      1                1984  ...  30185
# 6181                     NaN     12                1984  ...  18549
# 6182                     NaN      9                1999  ...  18549
#
#      element school distance(m) cluster  interest_rate  apartment_id  \
# 0                           165     6.0            2.5            21
# 1                           370     4.0            2.5            59
# 2                           460     3.0            2.5            18
# 3                           250     5.0            2.5            61
# 4                           650     0.0            2.5            50
# ...                         ...     ...            ...           ...
# 6178                        590     2.0            3.5            51
# 6179                        250     5.0            3.5            62
# 6180                        400     4.0            3.5             2
# 6181                        600     4.0            3.5            12
# 6182                        460     3.0            3.5            18
#
#       recent_price  size_sale percent  주택규모별floor  size_floor_price
# 0         220000.0          5  0.2110         616     220605.263158
# 1          73500.0          2  0.2110          35     146413.451777
# 2          68000.0          2  0.2110          38     137991.832461
# 3         180000.0          5  0.2110          65     222776.956522
# 4          30800.0          0  0.2110         120      32543.750000
# ...            ...        ...     ...         ...               ...
# 6178           NaN          5  0.1122         616     220605.263158
# 6179           NaN          4  0.1122         512     223707.142857
# 6180           NaN          2  0.1122          31     130105.027933
# 6181           NaN          2  0.1122         312     149775.000000
# 6182           NaN          2  0.1122          39     139513.280193
#
# [6183 rows x 28 columns]

# %% [markdown]
# ## 아파트 이름을 기준으로 아파트 가격 군집화 칼럼

# %%
from sklearn.cluster import KMeans
train = all_data[all_data['train_test'] == 'train']
train['transaction_real_price']=train['transaction_real_price'].replace('.', '').astype('int')
data = train[['apt_name','transaction_real_price']]
data
data = data.groupby(['apt_name']).mean()
arr = data['transaction_real_price'].to_numpy().reshape(-1, 1)

data
# 아파트 이름을 기준으로 아파트 가격 군집화
k = 20
kmeans = KMeans(n_clusters=k, n_init=10)
kmeans.fit(arr)

# 가격을 기준으로 군집의 순서를 정렬하기 위해 인덱스를 추출
sort_order = np.argsort(kmeans.cluster_centers_.flatten())

# 군집화 결과를 가격 순서대로 재할당
labels = np.zeros_like(kmeans.labels_)
for i, cluster in enumerate(sort_order):
    labels[kmeans.labels_ == cluster] = i

# 군집화 결과와 가격을 데이터에 추가
data['trade_price_with_apt_name'] = labels
data = data.reset_index()
data = data[['apt_name', 'trade_price_with_apt_name']]


all_data = pd.merge(all_data, data, how='left', left_on='apt_name', right_on='apt_name')
apt_name_mode = all_data.loc[all_data['train_test'] == 'train', 'trade_price_with_apt_name'].mode()
all_data['trade_price_with_apt_name'] = all_data['trade_price_with_apt_name'].fillna(apt_name_mode)




#fillna로 채워지지 않는 (977-) 아파트에 대해 apt_name_mode값 직접 입력
for i,x in enumerate(all_data['apt_name'].values):
    if x=='(977-)':
        all_data.iloc[i,-1]=apt_name_mode
# Out:
# /tmp/ipykernel_613906/1361873371.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['transaction_real_price']=train['transaction_real_price'].replace('.', '').astype('int')

# %%
all_data.iloc[:,-7]
# Out:
# 0       21
# 1       59
# 2       18
# 3       61
# 4       50
#         ..
# 6178    51
# 6179    62
# 6180     2
# 6181    12
# 6182    18
# Name: apartment_id, Length: 6183, dtype: int64

# %% [markdown]
# ## 층별 최근 가격 칼럼 넣기

# %%
def make_area_bucket(area):
    if area < 60: # 59타입
        return 0
    elif area < 85: # 84타입
        return 1
    else:
        return 2

all_data['bucket_area'] = all_data['exclusive_use_area'].apply(make_area_bucket)

def get_recent_floor_price(idx, all_data):
    temp_df = all_data.loc[:idx]
    temp_df = temp_df[
        (temp_df['transaction_date'] < row['transaction_date']) &
        (temp_df['bucket_area'] == row['bucket_area'])
    ]
    if len(temp_df) == 0:
        temp_df = all_data[
            (all_data['transaction_date'] < datetime.strptime('2016-01-01', "%Y-%m-%d")) &
            (all_data['bucket_area'] == row['bucket_area'])
        ]


    recent_floor_price = temp_df[(temp_df['apartment_id'] == row['apartment_id'])]
    recent_floor_price =  temp_df[(temp_df['floor'] == row['floor'])]
    if len(recent_floor_price) == 0:
        recent_floor_price = temp_df[(temp_df['sigungu'] == row['sigungu'])]
        recent_floor_price = recent_floor_price.iloc[-1]['transaction_real_price']
    else:
        recent_floor_price = recent_floor_price['transaction_real_price'].mean() 

    if recent_floor_price is None:
        recent_floor_price = temp_df['transaction_real_price'].mean() # 2019년 전체평균

    return recent_floor_price


for idx, row in tqdm(all_data.iterrows(), total = all_data.shape[0]):
    #if row['train_test'] == 'test':
        #continue
    all_data.loc[idx, 'recent_floor_price'] = get_recent_floor_price(idx, all_data)
# Out:
# 100%|████████████████████████████████████████| 6183/6183 [00:05<00:00, 1033.85it/s]

# %% [markdown]
# ## 대치동 전세 가격 칼럼 만들기

# %%
junse_price = pd.read_csv('/project/datacamp/team3/t3user1/서울시 부동산 전월세가 정보.csv',encoding='cp949')
# Out:
# /tmp/ipykernel_613906/2207834238.py:1: DtypeWarning: Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   junse_price = pd.read_csv('/project/datacamp/team3/t3user1/서울시 부동산 전월세가 정보.csv',encoding='cp949')

# %%
junse_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360702 entries, 0 to 360701
# Data columns (total 23 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   접수연도       360702 non-null  int64
#  1   자치구코드      360702 non-null  int64
#  2   자치구명       360702 non-null  object
#  3   법정동코드      360702 non-null  int64
#  4   법정동명       360702 non-null  object
#  5   지번구분       296141 non-null  float64
#  6   지번구분명      296141 non-null  object
#  7   본번         296217 non-null  float64
#  8   부번         296217 non-null  float64
#  9   층          295255 non-null  float64
#  10  계약일        360702 non-null  int64
#  11  전월세 구분     360702 non-null  object
#  12  임대면적(㎡)    360702 non-null  float64
#  13  보증금(만원)    360702 non-null  int64
#  14  임대료(만원)    360702 non-null  int64
#  15  건물명        296214 non-null  object
#  16  건축년도       356772 non-null  float64
#  17  건물용도       360702 non-null  object
#  18  계약기간       64188 non-null   object
#  19  신규갱신여부     61769 non-null   object
#  20  계약갱신권사용여부  10338 non-null   object
#  21  종전 보증금     55357 non-null   float64
#  22  종전 임대료     28718 non-null   float64
# dtypes: float64(8), int64(6), object(9)
# memory usage: 63.3+ MB

# %%
junse_price = junse_price[(junse_price['법정동명']=='대치동')&(junse_price['건물용도']=='아파트')&(junse_price['전월세 구분']=='전세')]
junse_price = junse_price[junse_price['접수연도'] >= 2014]
junse_price = junse_price[['접수연도','본번','층','임대면적(㎡)','건물명','보증금(만원)']]
junse_price['층'] = junse_price['층'].astype('int')
junse_price['junse_id'] = junse_price['접수연도'].astype('str')  + junse_price['임대면적(㎡)'].astype('str') + junse_price['건물명'].astype('str')

# %%
junse_price_gr = junse_price.groupby('junse_id')['보증금(만원)'].mean().reset_index()
junse_price_gr
# Out:
#                junse_id        보증금(만원)
# 0         2014101.6대치현대   70545.454545
# 1        2014105.18롯데캐슬   74000.000000
# 2     2014105.6삼환SOGOOD   65000.000000
# 3        2014107.91롯데캐슬   70200.000000
# 4        2014108.52대치삼성   87000.000000
# ...                 ...            ...
# 1671  202394.49래미안대치팰리스  169481.250000
# 1672  202394.51래미안대치팰리스  160000.000000
# 1673   202394.5래미안대치팰리스  172083.333333
# 1674    202397.24대치더클래스  130000.000000
# 1675      202397.35대치삼성  114579.545455
#
# [1676 rows x 2 columns]

# %%
all_data['junse_id'] = all_data['연도'].astype('str') + all_data['exclusive_use_area'].astype('str') + all_data['apt_name'].astype('str')

# %%
all_data['junse_price'] = 0

# %%
for i,x in enumerate(all_data[['junse_id','junse_price']].values):
    for ii, y in enumerate(junse_price_gr[['junse_id','보증금(만원)']].values):
        if x[0]==y[0] :
             all_data.iloc[i,-1]=junse_price_gr.iloc[ii,-1]
        else:
            pass

# %%
all_data.loc[all_data['junse_price'] > 0, 'junse_price'].median()
# Out:
# 73900.0

# %%
# 월세가 0인 값에 대해 중앙값 계산
median_junse_price = all_data.loc[all_data['junse_price'] > 0, 'junse_price'].median()

# 중앙값으로 채우기
all_data.loc[all_data['junse_price'] == 0, 'junse_price'] = median_junse_price

# %%
all_data.loc[all_data['junse_price'] == 73900 ]
# Out:
#               id        sigungu   jibun            apt_name  \
# 49    TRAIN_0082  서울특별시 강남구 대치동  891-26    대우아이빌멤버스(891-26)
# 80    TRAIN_0403  서울특별시 강남구 대치동    1025              롯데캐슬리베
# 93    TRAIN_0083  서울특별시 강남구 대치동  891-26    대우아이빌멤버스(891-26)
# 94    TRAIN_0479  서울특별시 강남구 대치동  890-54          선릉역풍림아이원레몬
# 118   TRAIN_0686  서울특별시 강남구 대치동   910-3  풍림아이원1차101동(910-3)
# ...          ...            ...     ...                 ...
# 6113   TEST_0157  서울특별시 강남구 대치동   891-6    테헤란로대우아이빌(891-6)
# 6131   TEST_0162  서울특별시 강남구 대치동   910-6         풍림아이원2차202동
# 6139   TEST_0062  서울특별시 강남구 대치동    1027            래미안대치팰리스
# 6156   TEST_0064  서울특별시 강남구 대치동    1027            래미안대치팰리스
# 6173   TEST_0193  서울특별시 강남구 대치동     511             한보미도맨션2
#
#       exclusive_use_area  transaction_year_month transaction_day  \
# 49               35.7960                  201401              14
# 80              121.0894                  201401              22
# 93               35.2360                  201401              27
# 94               69.8100                  201401              27
# 118              84.6900                  201402              10
# ...                  ...                     ...             ...
# 6113             66.8300                  202305              18
# 6131            137.4000                  202305              27
# 6139             91.9100                  202306              02
# 6156             91.8900                  202306              09
# 6173            190.4700                  202306              21
#
#       transaction_real_price  floor  year_of_completion  ... recent_price  \
# 49                   25000.0      9                2003  ...      29300.0
# 80                  119000.0      8                2008  ...     150000.0
# 93                   24000.0      7                2003  ...      25000.0
# 94                   40500.0      6                2006  ...      85000.0
# 118                  59700.0      6                2003  ...      90000.0
# ...                      ...    ...                 ...  ...          ...
# 6113                     NaN     26                2004  ...          NaN
# 6131                     NaN      6                2003  ...          NaN
# 6139                     NaN     26                2015  ...          NaN
# 6156                     NaN     17                2015  ...          NaN
# 6173                     NaN     13                1985  ...          NaN
#
#      size_sale percent  주택규모별floor  size_floor_price  \
# 49           0  0.2110          19      29341.304348
# 80           4  0.2110          58     205441.095890
# 93           0  0.2110          17      28373.478261
# 94           2  0.2110          36     139742.513369
# 118          2  0.3000          36     139742.513369
# ...        ...     ...         ...               ...
# 6113         2  0.2480         326      99500.000000
# 6131         5  0.2480          66     212302.210526
# 6139         3  0.1122         426          0.000000
# 6156         3  0.1122         417     203333.333333
# 6173         5  0.1122         613     257312.500000
#
#       trade_price_with_apt_name  bucket_area recent_floor_price  \
# 49                          0.0            0       29300.000000
# 80                         10.0            2      191500.000000
# 93                          0.0            0       76800.000000
# 94                          2.0            1       84500.000000
# 118                         4.0            1       75300.000000
# ...                         ...          ...                ...
# 6113                        1.0            1       99500.000000
# 6131                        5.0            2      183609.296970
# 6139                       17.0            2      254533.333333
# 6156                       17.0            2      207533.333333
# 6173                       14.0            2      213891.666667
#
#                          junse_id  junse_price
# 49     201435.796대우아이빌멤버스(891-26)      73900.0
# 80             2014121.0894롯데캐슬리베      73900.0
# 93     201435.236대우아이빌멤버스(891-26)      73900.0
# 94            201469.81선릉역풍림아이원레몬      73900.0
# 118   201484.69풍림아이원1차101동(910-3)      73900.0
# ...                           ...          ...
# 6113    202366.83테헤란로대우아이빌(891-6)      73900.0
# 6131         2023137.4풍림아이원2차202동      73900.0
# 6139            202391.91래미안대치팰리스      73900.0
# 6156            202391.89래미안대치팰리스      73900.0
# 6173            2023190.47한보미도맨션2      73900.0
#
# [342 rows x 33 columns]

# %% [markdown]
# # 상관관계 및 학습,검증

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6183 entries, 0 to 6182
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          6183 non-null   object
#  1   sigungu                     6183 non-null   object
#  2   jibun                       6183 non-null   object
#  3   apt_name                    6183 non-null   object
#  4   exclusive_use_area          6183 non-null   float64
#  5   transaction_year_month      6183 non-null   int64
#  6   transaction_day             6183 non-null   object
#  7   transaction_real_price      5987 non-null   float64
#  8   floor                       6183 non-null   int64
#  9   year_of_completion          6183 non-null   int64
#  10  train_test                  6183 non-null   object
#  11  transaction_date            6183 non-null   datetime64[ns]
#  12  주택규모별                       6183 non-null   object
#  13  연도                          6183 non-null   int32
#  14  월                           6183 non-null   int32
#  15  매매지수                        6183 non-null   float64
#  16  인구밀도                        5987 non-null   float64
#  17  daechi                      6183 non-null   object
#  18  동별인구밀도                      6183 non-null   int64
#  19  element school distance(m)  6183 non-null   int64
#  20  cluster                     6183 non-null   float64
#  21  interest_rate               6183 non-null   float64
#  22  apartment_id                6183 non-null   int64
#  23  recent_price                5987 non-null   float64
#  24  size_sale                   6183 non-null   int32
#  25  percent                     6183 non-null   float64
#  26  주택규모별floor                  6183 non-null   object
#  27  size_floor_price            6183 non-null   float64
#  28  trade_price_with_apt_name   6183 non-null   float64
#  29  bucket_area                 6183 non-null   int64
#  30  recent_floor_price          6183 non-null   float64
#  31  junse_id                    6183 non-null   object
#  32  junse_price                 6183 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int32(3), int64(7), object(10)
# memory usage: 1.5+ MB

# %%
all_data_copy=all_data
all_data_copy=all_data_copy.drop(['id','jibun','sigungu','apt_name','train_test','transaction_date','daechi','junse_id'], axis=1)
all_data_copy.corr()
# Out:
#                             exclusive_use_area  transaction_year_month  \
# exclusive_use_area                    1.000000               -0.044781
# transaction_year_month               -0.044781                1.000000
# transaction_day                       0.003427                0.022454
# transaction_real_price                0.627561                0.549810
# floor                                 0.057954                0.007617
# year_of_completion                    0.043118               -0.014561
# 주택규모별                                 0.970117               -0.038247
# 연도                                   -0.045360                0.999908
# 월                                     0.043776               -0.020303
# 매매지수                                  0.062460                0.858764
# 인구밀도                                  0.058583               -0.084674
# 동별인구밀도                                0.195090               -0.056462
# element school distance(m)           -0.259041                0.029211
# cluster                               0.510592               -0.008618
# interest_rate                         0.017216               -0.173633
# apartment_id                         -0.017862                0.060561
# recent_price                          0.620756                0.537253
# size_sale                             0.970117               -0.038247
# percent                               0.020086                0.239360
# 주택규모별floor                            0.390221               -0.004811
# size_floor_price                      0.913092               -0.024320
# trade_price_with_apt_name             0.639129                0.022014
# bucket_area                           0.857454               -0.021212
# recent_floor_price                    0.746450                0.341000
# junse_price                           0.691661                0.240157
#
#                             transaction_day  transaction_real_price     floor  \
# exclusive_use_area                 0.003427                0.627561  0.057954
# transaction_year_month             0.022454                0.549810  0.007617
# transaction_day                    1.000000                0.029999  0.006154
# transaction_real_price             0.029999                1.000000  0.138266
# floor                              0.006154                0.138266  1.000000
# year_of_completion                 0.008848               -0.000849  0.333011
# 주택규모별                              0.002213                0.615145  0.073401
# 연도                                 0.022572                0.548266  0.007331
# 월                                 -0.009254                0.125457  0.020883
# 매매지수                               0.002370                0.497436  0.040750
# 인구밀도                               0.019461               -0.063937 -0.006663
# 동별인구밀도                             0.006807                0.148173  0.184065
# element school distance(m)        -0.001973               -0.252039 -0.007674
# cluster                            0.010321                0.624279  0.097959
# interest_rate                     -0.029341               -0.321855 -0.021062
# apartment_id                      -0.002451               -0.069737 -0.179293
# recent_price                       0.028526                0.973714  0.117348
# size_sale                          0.002213                0.615145  0.073401
# percent                            0.028886                0.349821  0.004094
# 주택규모별floor                         0.012068                0.341173  0.752485
# size_floor_price                   0.013587                0.656549  0.209145
# trade_price_with_apt_name          0.016339                0.720208  0.165283
# bucket_area                        0.012413                0.582424  0.055432
# recent_floor_price                 0.022958                0.774865  0.242140
# junse_price                        0.011785                0.753817  0.282103
#
#                             year_of_completion     주택규모별        연도         월  \
# exclusive_use_area                    0.043118  0.970117 -0.045360  0.043776
# transaction_year_month               -0.014561 -0.038247  0.999908 -0.020303
# transaction_day                       0.008848  0.002213  0.022572 -0.009254
# transaction_real_price               -0.000849  0.615145  0.548266  0.125457
# floor                                 0.333011  0.073401  0.007331  0.020883
# year_of_completion                    1.000000  0.078556 -0.015743  0.087300
# 주택규모별                                 0.078556  1.000000 -0.038926  0.050945
# 연도                                   -0.015743 -0.038926  1.000000 -0.033895
# 월                                     0.087300  0.050945 -0.033895  1.000000
# 매매지수                                  0.039073  0.063398  0.857751  0.051244
# 인구밀도                                  0.013176  0.072197 -0.084885  0.010333
# 동별인구밀도                                0.483742  0.213834 -0.057296  0.062847
# element school distance(m)            0.059438 -0.266660  0.029152  0.003541
# cluster                              -0.107304  0.501265 -0.008590 -0.001820
# interest_rate                        -0.049989  0.007746 -0.171021 -0.187377
# apartment_id                         -0.473127 -0.032392  0.061337 -0.058717
# recent_price                         -0.003530  0.620952  0.535807  0.118496
# size_sale                             0.078556  1.000000 -0.038926  0.050945
# percent                               0.073584  0.029188  0.236277  0.220215
# 주택규모별floor                            0.199466  0.407562 -0.005165  0.026202
# size_floor_price                      0.049875  0.936371 -0.025034  0.053177
# trade_price_with_apt_name             0.003203  0.629370  0.021825  0.013323
# bucket_area                           0.059479  0.915451 -0.021899  0.051117
# recent_floor_price                    0.109681  0.800301  0.339748  0.082838
# junse_price                           0.459290  0.708285  0.239269  0.058748
#
#                                 매매지수  ...  apartment_id  recent_price  \
# exclusive_use_area          0.062460  ...     -0.017862      0.620756
# transaction_year_month      0.858764  ...      0.060561      0.537253
# transaction_day             0.002370  ...     -0.002451      0.028526
# transaction_real_price      0.497436  ...     -0.069737      0.973714
# floor                       0.040750  ...     -0.179293      0.117348
# year_of_completion          0.039073  ...     -0.473127     -0.003530
# 주택규모별                       0.063398  ...     -0.032392      0.620952
# 연도                          0.857751  ...      0.061337      0.535807
# 월                           0.051244  ...     -0.058717      0.118496
# 매매지수                        1.000000  ...      0.041780      0.484774
# 인구밀도                       -0.310278  ...      0.025167     -0.063932
# 동별인구밀도                      0.003100  ...     -0.456178      0.144849
# element school distance(m)  0.062777  ...     -0.266539     -0.262843
# cluster                    -0.067301  ...     -0.108471      0.625361
# interest_rate              -0.231094  ...     -0.001626     -0.310071
# apartment_id                0.041780  ...      1.000000     -0.061737
# recent_price                0.484774  ...     -0.061737      1.000000
# size_sale                   0.063398  ...     -0.032392      0.620952
# percent                     0.168325  ...     -0.028911      0.334249
# 주택규모별floor                  0.049517  ...     -0.128382      0.324300
# size_floor_price            0.016295  ...     -0.023409      0.657897
# trade_price_with_apt_name   0.001491  ...     -0.101178      0.719611
# bucket_area                 0.013126  ...     -0.027732      0.588634
# recent_floor_price          0.317718  ...     -0.050836      0.771442
# junse_price                 0.282269  ...     -0.321979      0.744940
#
#                             size_sale   percent  주택규모별floor  size_floor_price  \
# exclusive_use_area           0.970117  0.020086    0.390221          0.913092
# transaction_year_month      -0.038247  0.239360   -0.004811         -0.024320
# transaction_day              0.002213  0.028886    0.012068          0.013587
# transaction_real_price       0.615145  0.349821    0.341173          0.656549
# floor                        0.073401  0.004094    0.752485          0.209145
# year_of_completion           0.078556  0.073584    0.199466          0.049875
# 주택규모별                        1.000000  0.029188    0.407562          0.936371
# 연도                          -0.038926  0.236277   -0.005165         -0.025034
# 월                            0.050945  0.220215    0.026202          0.053177
# 매매지수                         0.063398  0.168325    0.049517          0.016295
# 인구밀도                         0.072197  0.079259    0.014121          0.087614
# 동별인구밀도                       0.213834  0.068731    0.161311          0.177112
# element school distance(m)  -0.266660 -0.018123   -0.118067         -0.293145
# cluster                      0.501265  0.046264    0.276919          0.579528
# interest_rate                0.007746 -0.434937   -0.000582         -0.007847
# apartment_id                -0.032392 -0.028911   -0.128382         -0.023409
# recent_price                 0.620952  0.334249    0.324300          0.657897
# size_sale                    1.000000  0.029188    0.407562          0.936371
# percent                      0.029188  1.000000    0.005573          0.044078
# 주택규모별floor                   0.407562  0.005573    1.000000          0.518320
# size_floor_price             0.936371  0.044078    0.518320          1.000000
# trade_price_with_apt_name    0.629370  0.053484    0.368245          0.684606
# bucket_area                  0.915451  0.035691    0.364134          0.893638
# recent_floor_price           0.800301  0.152303    0.482148          0.836953
# junse_price                  0.708285  0.141441    0.443375          0.707260
#
#                             trade_price_with_apt_name  bucket_area  \
# exclusive_use_area                           0.639129     0.857454
# transaction_year_month                       0.022014    -0.021212
# transaction_day                              0.016339     0.012413
# transaction_real_price                       0.720208     0.582424
# floor                                        0.165283     0.055432
# year_of_completion                           0.003203     0.059479
# 주택규모별                                        0.629370     0.915451
# 연도                                           0.021825    -0.021899
# 월                                            0.013323     0.051117
# 매매지수                                         0.001491     0.013126
# 인구밀도                                         0.092078     0.090798
# 동별인구밀도                                       0.235399     0.192443
# element school distance(m)                  -0.329268    -0.228953
# cluster                                      0.867228     0.493550
# interest_rate                               -0.011668    -0.005764
# apartment_id                                -0.101178    -0.027732
# recent_price                                 0.719611     0.588634
# size_sale                                    0.629370     0.915451
# percent                                      0.053484     0.035691
# 주택규모별floor                                   0.368245     0.364134
# size_floor_price                             0.684606     0.893638
# trade_price_with_apt_name                    1.000000     0.588406
# bucket_area                                  0.588406     1.000000
# recent_floor_price                           0.585026     0.871377
# junse_price                                  0.678974     0.651138
#
#                             recent_floor_price  junse_price
# exclusive_use_area                    0.746450     0.691661
# transaction_year_month                0.341000     0.240157
# transaction_day                       0.022958     0.011785
# transaction_real_price                0.774865     0.753817
# floor                                 0.242140     0.282103
# year_of_completion                    0.109681     0.459290
# 주택규모별                                 0.800301     0.708285
# 연도                                    0.339748     0.239269
# 월                                     0.082838     0.058748
# 매매지수                                  0.317718     0.282269
# 인구밀도                                  0.017774     0.054913
# 동별인구밀도                                0.174398     0.397369
# element school distance(m)           -0.210801    -0.243957
# cluster                               0.486324     0.534078
# interest_rate                        -0.081099    -0.132253
# apartment_id                         -0.050836    -0.321979
# recent_price                          0.771442     0.744940
# size_sale                             0.800301     0.708285
# percent                               0.152303     0.141441
# 주택규모별floor                            0.482148     0.443375
# size_floor_price                      0.836953     0.707260
# trade_price_with_apt_name             0.585026     0.678974
# bucket_area                           0.871377     0.651138
# recent_floor_price                    1.000000     0.733594
# junse_price                           0.733594     1.000000
#
# [25 rows x 25 columns]

# %%
# all_data의 id를 정렬하여 다시 저장
all_data = pd.concat([all_data[all_data['train_test'] == 'train'].sort_values('id',ascending=True),all_data[all_data['train_test'] == 'test'].sort_values('id',ascending=True)])
all_data
# Out:
#               id        sigungu jibun apt_name  exclusive_use_area  \
# 14    TRAIN_0000  서울특별시 강남구 대치동   503    개포우성1              158.54
# 26    TRAIN_0001  서울특별시 강남구 대치동   503    개포우성1              127.61
# 67    TRAIN_0002  서울특별시 강남구 대치동   503    개포우성1              127.61
# 116   TRAIN_0003  서울특별시 강남구 대치동   503    개포우성1              127.61
# 113   TRAIN_0004  서울특별시 강남구 대치동   503    개포우성1               84.81
# ...          ...            ...   ...      ...                 ...
# 6155   TEST_0191  서울특별시 강남구 대치동   511  한보미도맨션2               84.96
# 6169   TEST_0192  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 6173   TEST_0193  서울특별시 강남구 대치동   511  한보미도맨션2              190.47
# 6179   TEST_0194  서울특별시 강남구 대치동   511  한보미도맨션2              126.33
# 6054   TEST_0195  서울특별시 강남구 대치동   992      현대1               84.27
#
#       transaction_year_month transaction_day  transaction_real_price  floor  \
# 14                    201401              07                174000.0     13
# 26                    201401              09                157500.0      6
# 67                    201401              19                150000.0      5
# 116                   201402              10                152000.0      9
# 113                   201402              10                116000.0      3
# ...                      ...             ...                     ...    ...
# 6155                  202306              09                     NaN      1
# 6169                  202306              19                     NaN      1
# 6173                  202306              21                     NaN     13
# 6179                  202306              23                     NaN     12
# 6054                  202303              23                     NaN      3
#
#       year_of_completion  ... recent_price size_sale percent  주택규모별floor  \
# 14                  1983  ...     190000.0         5  0.2110         613
# 26                  1983  ...     132000.0         4  0.2110          56
# 67                  1983  ...     157500.0         4  0.2110          55
# 116                 1983  ...     150000.0         4  0.3000          59
# 113                 1983  ...      90000.0         2  0.3000          33
# ...                  ...  ...          ...       ...     ...         ...
# 6155                1985  ...          NaN         2  0.1122          31
# 6169                1985  ...          NaN         4  0.1122          51
# 6173                1985  ...          NaN         5  0.1122         613
# 6179                1985  ...          NaN         4  0.1122         512
# 6054                1990  ...          NaN         2  0.1020          33
#
#       size_floor_price  trade_price_with_apt_name  bucket_area  \
# 14       257312.500000                       16.0            2
# 26       180468.556701                       16.0            2
# 67       182710.869565                       16.0            2
# 116      197330.985915                       16.0            2
# 113      128725.872093                       16.0            1
# ...                ...                        ...          ...
# 6155     130105.027933                       14.0            1
# 6169     180797.402597                       14.0            2
# 6173     257312.500000                       14.0            2
# 6179     223707.142857                       14.0            2
# 6054     128725.872093                        6.0            1
#
#      recent_floor_price           junse_id    junse_price
# 14        132000.000000    2014158.54개포우성1  105571.428571
# 26        230000.000000    2014127.61개포우성1   86057.142857
# 67        156166.666667    2014127.61개포우성1   86057.142857
# 116       147500.000000    2014127.61개포우성1   86057.142857
# 113        83500.000000     201484.81개포우성1   64300.000000
# ...                 ...                ...            ...
# 6155      130318.079096   202384.96한보미도맨션2   76130.714286
# 6169      186559.349593  2023126.33한보미도맨션2  101692.307692
# 6173      213891.666667  2023190.47한보미도맨션2   73900.000000
# 6179      222702.692308  2023126.33한보미도맨션2  101692.307692
# 6054      128275.443787       202384.27현대1   46900.000000
#
# [6183 rows x 33 columns]

# %%
all_data_copy.columns
# Out:
# Index(['exclusive_use_area', 'transaction_year_month', 'transaction_day',
#        'transaction_real_price', 'floor', 'year_of_completion', '주택규모별', '연도',
#        '월', '매매지수', '인구밀도', '동별인구밀도', 'element school distance(m)', 'cluster',
#        'interest_rate', 'apartment_id', 'recent_price', 'size_sale', 'percent',
#        '주택규모별floor', 'size_floor_price', 'trade_price_with_apt_name',
#        'bucket_area', 'recent_floor_price', 'junse_price'],
#       dtype='object')

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (3.2.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (1.11.1)
# Requirement already satisfied: cmaes>=0.9.1 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (23.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (2.0.19)
# Requirement already satisfied: tqdm in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from alembic>=1.5.0->optuna) (4.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)

# %%
all_data['transaction_day'] = all_data['transaction_day'].astype(int)
all_data['주택규모별'] = all_data['주택규모별'].astype(int)
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6183 entries, 14 to 6054
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          6183 non-null   object
#  1   sigungu                     6183 non-null   object
#  2   jibun                       6183 non-null   object
#  3   apt_name                    6183 non-null   object
#  4   exclusive_use_area          6183 non-null   float64
#  5   transaction_year_month      6183 non-null   int64
#  6   transaction_day             6183 non-null   int64
#  7   transaction_real_price      5987 non-null   float64
#  8   floor                       6183 non-null   int64
#  9   year_of_completion          6183 non-null   int64
#  10  train_test                  6183 non-null   object
#  11  transaction_date            6183 non-null   datetime64[ns]
#  12  주택규모별                       6183 non-null   int64
#  13  연도                          6183 non-null   int32
#  14  월                           6183 non-null   int32
#  15  매매지수                        6183 non-null   float64
#  16  인구밀도                        5987 non-null   float64
#  17  daechi                      6183 non-null   object
#  18  동별인구밀도                      6183 non-null   int64
#  19  element school distance(m)  6183 non-null   int64
#  20  cluster                     6183 non-null   float64
#  21  interest_rate               6183 non-null   float64
#  22  apartment_id                6183 non-null   int64
#  23  recent_price                5987 non-null   float64
#  24  size_sale                   6183 non-null   int32
#  25  percent                     6183 non-null   float64
#  26  주택규모별floor                  6183 non-null   object
#  27  size_floor_price            6183 non-null   float64
#  28  trade_price_with_apt_name   6183 non-null   float64
#  29  bucket_area                 6183 non-null   int64
#  30  recent_floor_price          6183 non-null   float64
#  31  junse_id                    6183 non-null   object
#  32  junse_price                 6183 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int32(3), int64(9), object(8)
# memory usage: 1.5+ MB

# %%
all_data_copy[['exclusive_use_area', 'transaction_year_month',
       'transaction_real_price', 'floor', 'year_of_completion', '주택규모별',
     '매매지수', '동별인구밀도', 'cluster',
       'interest_rate', 'apartment_id', 'recent_price', 'size_sale', 'percent',
       '주택규모별floor', 'size_floor_price', 'trade_price_with_apt_name',
       'bucket_area', 'recent_floor_price', 'junse_price']].corr()
# Out:
#                            exclusive_use_area  transaction_year_month  \
# exclusive_use_area                   1.000000               -0.044781
# transaction_year_month              -0.044781                1.000000
# transaction_real_price               0.627561                0.549810
# floor                                0.057954                0.007617
# year_of_completion                   0.043118               -0.014561
# 주택규모별                                0.970117               -0.038247
# 매매지수                                 0.062460                0.858764
# 동별인구밀도                               0.195090               -0.056462
# cluster                              0.510592               -0.008618
# interest_rate                        0.017216               -0.173633
# apartment_id                        -0.017862                0.060561
# recent_price                         0.620756                0.537253
# size_sale                            0.970117               -0.038247
# percent                              0.020086                0.239360
# 주택규모별floor                           0.390221               -0.004811
# size_floor_price                     0.913092               -0.024320
# trade_price_with_apt_name            0.639129                0.022014
# bucket_area                          0.857454               -0.021212
# recent_floor_price                   0.746450                0.341000
# junse_price                          0.691661                0.240157
#
#                            transaction_real_price     floor  \
# exclusive_use_area                       0.627561  0.057954
# transaction_year_month                   0.549810  0.007617
# transaction_real_price                   1.000000  0.138266
# floor                                    0.138266  1.000000
# year_of_completion                      -0.000849  0.333011
# 주택규모별                                    0.615145  0.073401
# 매매지수                                     0.497436  0.040750
# 동별인구밀도                                   0.148173  0.184065
# cluster                                  0.624279  0.097959
# interest_rate                           -0.321855 -0.021062
# apartment_id                            -0.069737 -0.179293
# recent_price                             0.973714  0.117348
# size_sale                                0.615145  0.073401
# percent                                  0.349821  0.004094
# 주택규모별floor                               0.341173  0.752485
# size_floor_price                         0.656549  0.209145
# trade_price_with_apt_name                0.720208  0.165283
# bucket_area                              0.582424  0.055432
# recent_floor_price                       0.774865  0.242140
# junse_price                              0.753817  0.282103
#
#                            year_of_completion     주택규모별      매매지수    동별인구밀도  \
# exclusive_use_area                   0.043118  0.970117  0.062460  0.195090
# transaction_year_month              -0.014561 -0.038247  0.858764 -0.056462
# transaction_real_price              -0.000849  0.615145  0.497436  0.148173
# floor                                0.333011  0.073401  0.040750  0.184065
# year_of_completion                   1.000000  0.078556  0.039073  0.483742
# 주택규모별                                0.078556  1.000000  0.063398  0.213834
# 매매지수                                 0.039073  0.063398  1.000000  0.003100
# 동별인구밀도                               0.483742  0.213834  0.003100  1.000000
# cluster                             -0.107304  0.501265 -0.067301  0.057765
# interest_rate                       -0.049989  0.007746 -0.231094 -0.087916
# apartment_id                        -0.473127 -0.032392  0.041780 -0.456178
# recent_price                        -0.003530  0.620952  0.484774  0.144849
# size_sale                            0.078556  1.000000  0.063398  0.213834
# percent                              0.073584  0.029188  0.168325  0.068731
# 주택규모별floor                           0.199466  0.407562  0.049517  0.161311
# size_floor_price                     0.049875  0.936371  0.016295  0.177112
# trade_price_with_apt_name            0.003203  0.629370  0.001491  0.235399
# bucket_area                          0.059479  0.915451  0.013126  0.192443
# recent_floor_price                   0.109681  0.800301  0.317718  0.174398
# junse_price                          0.459290  0.708285  0.282269  0.397369
#
#                             cluster  interest_rate  apartment_id  \
# exclusive_use_area         0.510592       0.017216     -0.017862
# transaction_year_month    -0.008618      -0.173633      0.060561
# transaction_real_price     0.624279      -0.321855     -0.069737
# floor                      0.097959      -0.021062     -0.179293
# year_of_completion        -0.107304      -0.049989     -0.473127
# 주택규모별                      0.501265       0.007746     -0.032392
# 매매지수                      -0.067301      -0.231094      0.041780
# 동별인구밀도                     0.057765      -0.087916     -0.456178
# cluster                    1.000000       0.004591     -0.108471
# interest_rate              0.004591       1.000000     -0.001626
# apartment_id              -0.108471      -0.001626      1.000000
# recent_price               0.625361      -0.310071     -0.061737
# size_sale                  0.501265       0.007746     -0.032392
# percent                    0.046264      -0.434937     -0.028911
# 주택규모별floor                 0.276919      -0.000582     -0.128382
# size_floor_price           0.579528      -0.007847     -0.023409
# trade_price_with_apt_name  0.867228      -0.011668     -0.101178
# bucket_area                0.493550      -0.005764     -0.027732
# recent_floor_price         0.486324      -0.081099     -0.050836
# junse_price                0.534078      -0.132253     -0.321979
#
#                            recent_price  size_sale   percent  주택규모별floor  \
# exclusive_use_area             0.620756   0.970117  0.020086    0.390221
# transaction_year_month         0.537253  -0.038247  0.239360   -0.004811
# transaction_real_price         0.973714   0.615145  0.349821    0.341173
# floor                          0.117348   0.073401  0.004094    0.752485
# year_of_completion            -0.003530   0.078556  0.073584    0.199466
# 주택규모별                          0.620952   1.000000  0.029188    0.407562
# 매매지수                           0.484774   0.063398  0.168325    0.049517
# 동별인구밀도                         0.144849   0.213834  0.068731    0.161311
# cluster                        0.625361   0.501265  0.046264    0.276919
# interest_rate                 -0.310071   0.007746 -0.434937   -0.000582
# apartment_id                  -0.061737  -0.032392 -0.028911   -0.128382
# recent_price                   1.000000   0.620952  0.334249    0.324300
# size_sale                      0.620952   1.000000  0.029188    0.407562
# percent                        0.334249   0.029188  1.000000    0.005573
# 주택규모별floor                     0.324300   0.407562  0.005573    1.000000
# size_floor_price               0.657897   0.936371  0.044078    0.518320
# trade_price_with_apt_name      0.719611   0.629370  0.053484    0.368245
# bucket_area                    0.588634   0.915451  0.035691    0.364134
# recent_floor_price             0.771442   0.800301  0.152303    0.482148
# junse_price                    0.744940   0.708285  0.141441    0.443375
#
#                            size_floor_price  trade_price_with_apt_name  \
# exclusive_use_area                 0.913092                   0.639129
# transaction_year_month            -0.024320                   0.022014
# transaction_real_price             0.656549                   0.720208
# floor                              0.209145                   0.165283
# year_of_completion                 0.049875                   0.003203
# 주택규모별                              0.936371                   0.629370
# 매매지수                               0.016295                   0.001491
# 동별인구밀도                             0.177112                   0.235399
# cluster                            0.579528                   0.867228
# interest_rate                     -0.007847                  -0.011668
# apartment_id                      -0.023409                  -0.101178
# recent_price                       0.657897                   0.719611
# size_sale                          0.936371                   0.629370
# percent                            0.044078                   0.053484
# 주택규모별floor                         0.518320                   0.368245
# size_floor_price                   1.000000                   0.684606
# trade_price_with_apt_name          0.684606                   1.000000
# bucket_area                        0.893638                   0.588406
# recent_floor_price                 0.836953                   0.585026
# junse_price                        0.707260                   0.678974
#
#                            bucket_area  recent_floor_price  junse_price
# exclusive_use_area            0.857454            0.746450     0.691661
# transaction_year_month       -0.021212            0.341000     0.240157
# transaction_real_price        0.582424            0.774865     0.753817
# floor                         0.055432            0.242140     0.282103
# year_of_completion            0.059479            0.109681     0.459290
# 주택규모별                         0.915451            0.800301     0.708285
# 매매지수                          0.013126            0.317718     0.282269
# 동별인구밀도                        0.192443            0.174398     0.397369
# cluster                       0.493550            0.486324     0.534078
# interest_rate                -0.005764           -0.081099    -0.132253
# apartment_id                 -0.027732           -0.050836    -0.321979
# recent_price                  0.588634            0.771442     0.744940
# size_sale                     0.915451            0.800301     0.708285
# percent                       0.035691            0.152303     0.141441
# 주택규모별floor                    0.364134            0.482148     0.443375
# size_floor_price              0.893638            0.836953     0.707260
# trade_price_with_apt_name     0.588406            0.585026     0.678974
# bucket_area                   1.000000            0.871377     0.651138
# recent_floor_price            0.871377            1.000000     0.733594
# junse_price                   0.651138            0.733594     1.000000

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(all_data_copy.corr(), cmap='coolwarm', annot=True, fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /home/t3user1/.conda/envs/kmj/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_squared_error

# import optuna

# validation_year = 2022

# columns = [ 'exclusive_use_area', 'cluster','recent_price','size_sale','size_floor_price','recent_floor_price','연도','월','interest_rate'
# ]

# train_x = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] < validation_year), columns]
# train_y = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] < validation_year), 'transaction_real_price']

# val_x = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] == validation_year), columns]
# val_y = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] == validation_year), 'transaction_real_price']

# def objective(trial):
#     # 하이퍼파라미터 탐색 대상
#     n_estimators = trial.suggest_int('n_estimators', 10, 100)
#     max_depth = trial.suggest_int('max_depth', 2, 32)

#     # RandomForestRegressor 모델 학습
#     model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth)
#     model.fit(train_x, train_y)

#     # 검증 데이터로 평가
#     y_pred = model.predict(val_x)
#     mse = mean_squared_error(val_y, y_pred)
#     return mse

# # Optuna를 사용하여 하이퍼파라미터 탐색
# study = optuna.create_study(direction='minimize')  # 목표는 최소화
# study.optimize(objective, n_trials=50)  # 50회 반복하여 탐색

# # 최적의 하이퍼파라미터 값 출력
# best_params_rf = study.best_params
# print("Best Params:", best_params_rf)

# %%
from sklearn.model_selection import StratifiedKFold # StratifiedKFold 
from catboost import CatBoostClassifier, CatBoostRegressor # catboost
from sklearn.metrics import mean_squared_error
import optuna

validation_year = 2022

columns = [ 'exclusive_use_area', 'cluster','size_sale','size_floor_price','recent_floor_price','연도','월','interest_rate','trade_price_with_apt_name']


train_x = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] < validation_year), columns]
train_y = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] < validation_year), 'transaction_real_price']

val_x = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] == validation_year), columns]
val_y = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] == validation_year), 'transaction_real_price']






def objective(trial):

    cbrm_param = {
        'iterations':trial.suggest_int('iterations', 1, 1000),
        'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
        'depth': trial.suggest_int('depth',1, 16),
        'random_state' : 7
    }

    # Generate model
    model_cbrm = CatBoostRegressor(**cbrm_param)
    model_cbrm = model_cbrm.fit(train_x, train_y, eval_set=[(val_x, val_y)], 
                           verbose=0, early_stopping_rounds=25)
                           
    # 평가지표 원하는 평가 지표가 있을 시 바꾸어 준다.
    MSE = mean_squared_error(val_y, model_cbrm.predict(val_x))
    return MSE

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials = 50)
best_params_cb = study.best_params
print("Best Params:", best_params_cb)
# Out:
# [I 2023-08-02 23:45:29,534] A new study created in memory with name: no-name-b266ebb3-4eac-4eeb-a125-ed2860a5b1f1
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:29,706] Trial 0 finished with value: 2513645952.142479 and parameters: {'iterations': 120, 'learning_rate': 0.3795863446633273, 'depth': 6}. Best is trial 0 with value: 2513645952.142479.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:29,836] Trial 1 finished with value: 1442103522.791463 and parameters: {'iterations': 74, 'learning_rate': 0.7778961080804702, 'depth': 6}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:30,137] Trial 2 finished with value: 1780984100.3081849 and parameters: {'iterations': 453, 'learning_rate': 0.17238768441167174, 'depth': 6}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:56,539] Trial 3 finished with value: 4919443342.246988 and parameters: {'iterations': 784, 'learning_rate': 0.11240815358872591, 'depth': 16}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:57,171] Trial 4 finished with value: 5603182643.66325 and parameters: {'iterations': 551, 'learning_rate': 0.9260964498689216, 'depth': 13}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:57,495] Trial 5 finished with value: 1462361461.651739 and parameters: {'iterations': 731, 'learning_rate': 0.09698774983810299, 'depth': 2}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:57,717] Trial 6 finished with value: 1652383418.7134001 and parameters: {'iterations': 605, 'learning_rate': 0.20393708380653486, 'depth': 4}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:57,952] Trial 7 finished with value: 2341188575.614836 and parameters: {'iterations': 305, 'learning_rate': 0.026037920517086977, 'depth': 3}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45:58,243] Trial 8 finished with value: 2732849951.913829 and parameters: {'iterations': 851, 'learning_rate': 0.419554476412045, 'depth': 8}. Best is trial 1 with value: 1442103522.791463.
# /tmp/ipykernel_613906/535281302.py:26: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate' : trial.suggest_uniform('learning_rate',0, 1),
# [I 2023-08-02 23:45
. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:46:51,131] Trial 39 finished with value: 2506736081.277855 and parameters: {'n_estimators': 85, 'max_depth': 21, 'learning_rate': 0.19516521925202646}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:46:53,847] Trial 40 finished with value: 2241736203.8790298 and parameters: {'n_estimators': 91, 'max_depth': 24, 'learning_rate': 0.09334737617532149}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:46:55,191] Trial 41 finished with value: 2275666258.965395 and parameters: {'n_estimators': 74, 'max_depth': 19, 'learning_rate': 0.13052667956357064}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:46:55,303] Trial 42 finished with value: 37882232316.372665 and parameters: {'n_estimators': 47, 'max_depth': 22, 'learning_rate': 0.008378076736669961}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:46:57,917] Trial 43 finished with value: 2254925547.7456865 and parameters: {'n_estimators': 89, 'max_depth': 25, 'learning_rate': 0.13497411254565408}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:46:59,132] Trial 44 finished with value: 2207527030.6226063 and parameters: {'n_estimators': 67, 'max_depth': 21, 'learning_rate': 0.10231148651501716}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:47:00,120] Trial 45 finished with value: 2230606123.862458 and parameters: {'n_estimators': 61, 'max_depth': 21, 'learning_rate': 0.081523256202298}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:47:02,391] Trial 46 finished with value: 2343277990.305282 and parameters: {'n_estimators': 70, 'max_depth': 27, 'learning_rate': 0.16707810146662938}. Best is trial 38 with value: 2162690601.7995934.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:47:02,631] Trial 47 finished with value: 2099288576.2184505 and parameters: {'n_estimators': 51, 'max_depth': 4, 'learning_rate': 0.10447640883020651}. Best is trial 47 with value: 2099288576.2184505.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:47:03,759] Trial 48 finished with value: 2484445778.5259194 and parameters: {'n_estimators': 58, 'max_depth': 23, 'learning_rate': 0.10676858534603532}. Best is trial 47 with value: 2099288576.2184505.
# /tmp/ipykernel_613906/3560772862.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.2)
# [I 2023-08-02 23:47:03,831] Trial 49 finished with value: 2830472932.1051965 and parameters: {'n_estimators': 48, 'max_depth': 5, 'learning_rate': 0.06940716872520342}. Best is trial 47 with value: 2099288576.2184505.
# Best Params: {'n_estimators': 51, 'max_depth': 4, 'learning_rate': 0.10447640883020651}

# %%
from lightgbm import LGBMRegressor
import numpy as np

def objective(trial):
    # 하이퍼파라미터 탐색 대상
    n_estimators = trial.suggest_int('n_estimators', 10, 500)
    max_depth = trial.suggest_int('max_depth', 2, 32)
    learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)

    # LightGBMRegressor 모델 학습
    model = LGBMRegressor(n_estimators=n_estimators,
                          max_depth=max_depth,
                          learning_rate=learning_rate,
                          random_state=7)
    model.fit(train_x, train_y)

    # 모델 예측
    val_pred = model.predict(val_x)

    # 평가 지표로 평균 제곱 오차 (Mean Squared Error, MSE)를 사용
    mse = np.mean((val_pred - val_y) ** 2)

    return mse

# Optuna를 사용하여 하이퍼파라미터 탐색
study = optuna.create_study(direction='minimize')  # 목표는 최소화
study.optimize(objective, n_trials=50)  # 50회 반복하여 탐색

# 최적의 하이퍼파라미터 값 출력
best_params_LGBM = study.best_params
print("Best Params:", best_params_LGBM)
# Out:
# [I 2023-08-02 23:47:03,848] A new study created in memory with name: no-name-af58fc34-154d-47c4-b15d-aabe23c09179
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:04,211] Trial 0 finished with value: 1886288460.3873546 and parameters: {'n_estimators': 453, 'max_depth': 10, 'learning_rate': 0.013991212577585206}. Best is trial 0 with value: 1886288460.3873546.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:04
. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:14,025] Trial 39 finished with value: 1841780185.8525615 and parameters: {'n_estimators': 358, 'max_depth': 13, 'learning_rate': 0.02224535990431345}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:14,312] Trial 40 finished with value: 1770248043.2957876 and parameters: {'n_estimators': 320, 'max_depth': 27, 'learning_rate': 0.03030837149221619}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:14,662] Trial 41 finished with value: 1637440797.7139292 and parameters: {'n_estimators': 499, 'max_depth': 29, 'learning_rate': 0.06391709235724922}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:14,979] Trial 42 finished with value: 1669029315.6220374 and parameters: {'n_estimators': 475, 'max_depth': 28, 'learning_rate': 0.0770952364852517}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:15,324] Trial 43 finished with value: 1602144857.5083122 and parameters: {'n_estimators': 444, 'max_depth': 30, 'learning_rate': 0.05406210058736118}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:15,667] Trial 44 finished with value: 1601893421.651251 and parameters: {'n_estimators': 442, 'max_depth': 25, 'learning_rate': 0.051483404528529876}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:15,986] Trial 45 finished with value: 1739808984.8422034 and parameters: {'n_estimators': 371, 'max_depth': 25, 'learning_rate': 0.03926930386630384}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:16,170] Trial 46 finished with value: 1846445395.9814234 and parameters: {'n_estimators': 248, 'max_depth': 30, 'learning_rate': 0.03277323923468376}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:16,295] Trial 47 finished with value: 1924355520.1528485 and parameters: {'n_estimators': 70, 'max_depth': 21, 'learning_rate': 0.08939909310492189}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:16,623] Trial 48 finished with value: 1593433834.3968625 and parameters: {'n_estimators': 415, 'max_depth': 23, 'learning_rate': 0.05295886455994975}. Best is trial 20 with value: 1528255803.222312.
# /tmp/ipykernel_613906/2541933366.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 0.001, 0.1)
# [I 2023-08-02 23:47:16,791] Trial 49 finished with value: 1746337670.7340996 and parameters: {'n_estimators': 225, 'max_depth': 23, 'learning_rate': 0.04416589013615294}. Best is trial 20 with value: 1528255803.222312.
# Best Params: {'n_estimators': 400, 'max_depth': 25, 'learning_rate': 0.05633966458489866}

# %%
from sklearn.metrics import mean_absolute_error

for validation_year in [2018, 2019, 2020, 2021, 2022]:
    columns = [ 
'exclusive_use_area', 'cluster','size_sale','size_floor_price','recent_floor_price','연도','월','interest_rate','trade_price_with_apt_name'
    ]
    train_x = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] < validation_year), columns]
    train_y = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] < validation_year), 'transaction_real_price']

    val_x = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] == validation_year), columns]
    val_y = all_data.loc[(all_data['train_test'] == 'train') & (all_data['연도'] == validation_year), 'transaction_real_price']

# 모델 생성 및 훈련
#    model_rf = RandomForestRegressor(n_estimators=best_params_rf['n_estimators'],
#                                     max_depth=best_params_rf['max_depth'],
#                                     random_state=7
#                                     )
#    model_rf.fit(train_x, train_y)

    model_xgb = xgb.XGBRegressor(n_estimators=best_params_xgb['n_estimators'],
                              max_depth=best_params_xgb['max_depth'],
                              learning_rate=best_params_xgb['learning_rate'],
                              random_state=7)
    model_xgb.fit(train_x, train_y)
    
    model_cb = CatBoostRegressor(iterations=best_params_cb['iterations'],
                depth=best_params_cb['depth'],
                 learning_rate= best_params_cb['learning_rate']
                ,verbose=0)

    model_cb.fit(train_x, train_y)

    model_LGBM = CatBoostRegressor(iterations=best_params_cb['iterations'],
                 depth=best_params_cb['depth'],
                 learning_rate= best_params_cb['learning_rate']
                ,verbose=0)

    model_LGBM.fit(train_x, train_y)

    #예측
    pred_cb_ls = model_cb.predict(val_x)
    pred_xgb_ls = model_xgb.predict(val_x)
    pred_LGBM_ls = model_LGBM.predict(val_x)
    blended_prediction = (pred_cb_ls + pred_xgb_ls+pred_LGBM_ls)/3
    
    mae1 = mean_absolute_error(blended_prediction, val_y)
    mae2 = mean_absolute_error(pred_cb_ls, val_y)
    mae3 = mean_absolute_error(pred_xgb_ls, val_y)
    mae4 = mean_absolute_error(pred_LGBM_ls, val_y)
    print(validation_year,'년도 MAE_bp: ' , mae1)
    print(validation_year,'년도 MAE_cb: ' , mae2)
    print(validation_year,'년도 MAE_xbb: ' , mae3)
    print(validation_year,'년도 MAE_lgbm: ' , mae4)
    print('----------------------------------------')
# Out:
# 2018 년도 MAE_bp:  36507.752348486014
# 2018 년도 MAE_cb:  34478.922435055225
# 2018 년도 MAE_xbb:  41012.64457738681
# 2018 년도 MAE_lgbm:  34478.922435055225
# ----------------------------------------
# 2019 년도 MAE_bp:  23020.68608189075
# 2019 년도 MAE_cb:  21746.48147167881
# 2019 년도 MAE_xbb:  26240.206575768378
# 2019 년도 MAE_lgbm:  21746.48147167881
# ----------------------------------------
# 2020 년도 MAE_bp:  23710.937772227986
# 2020 년도 MAE_cb:  21956.14599110371
# 2020 년도 MAE_xbb:  28318.04297886982
# 2020 년도 MAE_lgbm:  21956.14599110371
# ----------------------------------------
# 2021 년도 MAE_bp:  37511.17991679065
# 2021 년도 MAE_cb:  37803.1706498559
# 2021 년도 MAE_xbb:  38168.95682730924
# 2021 년도 MAE_lgbm:  37803.1706498559
# ----------------------------------------
# 2022 년도 MAE_bp:  26575.657988430226
# 2022 년도 MAE_cb:  26844.78679842797
# 2022 년도 MAE_xbb:  33718.61329780191
# 2022 년도 MAE_lgbm:  26844.78679842797
# ----------------------------------------

# %%
from sklearn.ensemble import RandomForestRegressor


#columns = ['exclusive_use_area', 'cluster','size_sale','size_floor_price','recent_floor_price','연도','월','interest_rate','trade_price_with_apt_name','주택규모별']
train_x = all_data.loc[all_data['train_test'] == 'train', columns]
train_y = all_data.loc[all_data['train_test'] == 'train', 'transaction_real_price']
test_x = all_data.loc[all_data['train_test'] == 'test', columns]

# 모델 생성 및 훈련
#model_rf = RandomForestRegressor(n_estimators=best_params_rf['n_estimators'],
#                                 max_depth=best_params_rf['max_depth'],
#                                 random_state=7)
#model_rf.fit(train_x, train_y)

model_xgb = xgb.XGBRegressor(n_estimators=best_params_xgb['n_estimators'],
                          max_depth=best_params_xgb['max_depth'],
                          learning_rate=best_params_xgb['learning_rate'],
                          random_state=7)
model_xgb.fit(train_x, train_y)

model_cb = CatBoostRegressor(iterations=best_params_cb['iterations'],
                depth=best_params_cb['depth'],
                 learning_rate= best_params_cb['learning_rate'])

model_cb.fit(train_x, train_y)

model_LGBM = CatBoostRegressor(iterations=best_params_cb['iterations'],
                depth=best_params_cb['depth'],
                 learning_rate= best_params_cb['learning_rate'])

model_LGBM.fit(train_x, train_y)

# 예측
pred_ls = list()
pred_ls_cb = list()
pred_ls_xgb = list()
pred_ls_LGBM = list()

now_df = all_data.loc[all_data['train_test'] == 'train']
test = all_data.loc[all_data['train_test'] == 'test']

for idx, row in tqdm(test.iterrows(), total = test.shape[0]):
    now_df = pd.concat([now_df, test.loc[[idx]]])
#    test_x.loc[idx, 'recent_price'] = get_recent_price(idx, now_df)
    
    # 예측
    pred_cb_ls = model_cb.predict(test_x.loc[idx:idx])
#    pred_rf_ls = model_rf.predict(test_x.loc[idx:idx])
    pred_xgb_ls = model_xgb.predict(test_x.loc[idx:idx])
    pred_LGBM_ls = model_xgb.predict(test_x.loc[idx:idx])
    
    blended_prediction = (pred_cb_ls + pred_xgb_ls + pred_LGBM_ls)/3
    
    now_df.loc[idx, 'transaction_real_price'] = blended_prediction
    pred_ls.append(blended_prediction[0])
    pred_ls_cb.append(pred_cb_ls[0])
    pred_ls_xgb.append(pred_xgb_ls[0])
    pred_ls_LGBM.append(pred_LGBM_ls[0])
# Out:
# 0:	learn: 52367.2275303	total: 454us	remaining: 128ms
# 1:	learn: 39316.7901373	total: 844us	remaining: 119ms
# 2:	learn: 34652.3627736	total: 1.25ms	remaining: 116ms
# 3:	learn: 32310.1251507	total: 1.65ms	remaining: 115ms
# 4:	learn: 29044.6695160	total: 2.01ms	remaining: 112ms
# 5:	learn: 27724.7262830	total: 2.31ms	remaining: 107ms
# 6:	learn: 26680.6933133	total: 2.6ms	remaining: 103ms
# 7:	learn: 25555.9528331	total: 2.85ms	remaining: 97.9ms
# 8:	learn: 23799.1194175	total: 3.08ms	remaining: 93.8ms
# 9:	learn: 23055.6229116	total: 3.33ms	remaining: 90.9ms
# 10:	learn: 22438.1622247	total: 3.56ms	remaining: 88ms
# 11:	learn: 21824.3097776	total: 3.77ms	remaining: 85.2ms
# 12:	learn: 21133.6330532	total: 4.02ms	remaining: 83.5ms
# 13:	learn: 20702.3879214	total: 4.27ms	remaining: 82.1ms
# 14:	learn: 20266.0153531	total: 4.51ms	remaining: 80.7ms
# 15:	learn: 20063.7124020	total: 4.75ms	remaining: 79.3ms
# 16:	learn: 19827.1177338	total: 4.97ms	remaining: 77.8ms
# 17:	learn: 19450.4976698	total: 5.21ms	remaining: 76.7ms
# 18:	learn: 18919.1497114	total: 5.44ms	remaining: 75.6ms
# 19:	learn: 18633.1679874	total: 5.68ms	remaining: 74.8ms
# 20:	learn: 18259.5157832	total: 5.92ms	remaining: 73.9ms
# 21:	learn: 18002.4026200	total: 6.15ms	remaining: 73ms
# 22:	learn: 17677.4019062	total: 6.39ms	remaining: 72.2ms
# 23:	learn: 17382.2346677	total: 6.63ms	remaining: 71.6ms
# 24:	learn: 17200.9898491	total: 6.88ms	remaining: 71ms
# 25:	learn: 17064.5565873	total: 7.13ms	remaining: 70.4ms
# 26:	learn: 16889.5565665	total: 7.37ms	remaining: 69.9ms
# 27:	learn: 16710.0389694	total: 7.61ms	remaining: 69.3ms
# 28:	learn: 16594.6861214	total: 7.86ms	remaining: 68.9ms
# 266:	learn: 9090.1703345	total: 66ms	remaining: 3.96ms
# 267:	learn: 9086.9168389	total: 66.3ms	remaining: 3.71ms
# 268:	learn: 9079.6921054	total: 66.5ms	remaining: 3.46ms
# 269:	learn: 9072.0741713	total: 66.7ms	remaining: 3.21ms
# 270:	learn: 9037.4017941	total: 67ms	remaining: 2.97ms
# 271:	learn: 9027.5363027	total: 67.2ms	remaining: 2.72ms
# 272:	learn: 9021.5533697	total: 67.4ms	remaining: 2.47ms
# 273:	learn: 9011.8181530	total: 67.7ms	remaining: 2.22ms
# 274:	learn: 9006.5109919	total: 67.9ms	remaining: 1.98ms
# 275:	learn: 8993.7796873	total: 68.2ms	remaining: 1.73ms
# 276:	learn: 8987.3555501	total: 68.4ms	remaining: 1.48ms
# 277:	learn: 8978.1126288	total: 68.7ms	remaining: 1.24ms
# 278:	learn: 8953.6364339	total: 68.9ms	remaining: 988us
# 279:	learn: 8944.3943435	total: 69.2ms	remaining: 741us
# 280:	learn: 8935.9411663	total: 69.4ms	remaining: 494us
# 281:	learn: 8916.8786897	total: 69.7ms	remaining: 247us
# 282:	learn: 8913.6293852	total: 69.9ms	remaining: 0us
# 100%|███████████████████████████████████████████| 196/196 [00:01<00:00, 138.26it/s]

# %%
submission = pd.read_csv('sample_submission.csv')
submission1 = pd.read_csv('sample_submission.csv')
submission2 = pd.read_csv('sample_submission.csv')
submission3 = pd.read_csv('sample_submission.csv')

submission['transaction_real_price'] = pred_ls
submission1['transaction_real_price'] = pred_ls_cb
submission2['transaction_real_price'] = pred_ls_xgb
submission3['transaction_real_price'] = pred_ls_LGBM
submission.to_csv('sub_blended.csv', index=False)
submission1.to_csv('sub_cb.csv', index=False)
submission2.to_csv('sub_xgb.csv', index=False)
submission3.to_csv('sub_LGBM.csv', index=False)

# %%
print(submission['transaction_real_price'])
print('------------------------------------')
print(submission1['transaction_real_price'])
print('------------------------------------')
print(submission2['transaction_real_price'])
print('------------------------------------')
print(submission3['transaction_real_price'])
# Out:
# 0      193577.870526
# 1      148022.857914
# 2      272462.320436
# 3      276589.766256
# 4      275757.516636
#            ...
# 191    263263.521740
# 192    337851.419175
# 193    422558.544789
# 194    347319.538165
# 195    160315.809052
# Name: transaction_real_price, Length: 196, dtype: float64
# ------------------------------------
# 0      174620.205329
# 1      135356.167491
# 2      231703.586307
# 3      242923.361269
# 4      237703.487408
#            ...
# 191    224677.065221
# 192    310297.445026
# 193    401255.884367
# 194    321325.864496
# 195    148295.802155
# Name: transaction_real_price, Length: 196, dtype: float64
# ------------------------------------
# 0      203056.703125
# 1      154356.203125
# 2      292841.687500
# 3      293422.968750
# 4      294784.531250
#            ...
# 191    282556.750000
# 192    351628.406250
# 193    433209.875000
# 194    360316.375000
# 195    166325.812500
# Name: transaction_real_price, Length: 196, dtype: float32
# ------------------------------------
# 0      203056.703125
# 1      154356.203125
# 2      292841.687500
# 3      293422.968750
# 4      294784.531250
#            ...
# 191    282556.750000
# 192    351628.406250
# 193    433209.875000
# 194    360316.375000
# 195    166325.812500
# Name: transaction_real_price, Length: 196, dtype: float32
